# %% [markdown]
# # Chapitre 4.3 - Les fichiers CSV, JSON et les requêtes
#
# ---
#
# ## 1. La structure du web : comment communique-t-on avec un serveur ?
#
# ![Anatomie d'une communication HTTP](images/http.request.scheme.png)
#
# Lors d'une communication HTTP avec un serveur, la communication est divisible en deux : l'envoi de la requête et la réponse du serveur. Ces deux éléments de la communication répondent à un ensemble de standards très stricts permettant le fonctionnement du web tel que nous le connaissons.

# %% [markdown]
# ### 1.A. Anatomie d'une requête :
#
# ![Anatomie d'une requête HTTP](images/http.request.request.png)
#
# La requête, c'est-à-dire l'information envoyée au serveur, est composée à minima de trois types d'informations :
#
# - l'URL
# - la méthode
# - les headers
#
# #### URL
#
# Voir le [schéma](images/url.png) ([Source](https://cascadingmedia.com/assets/images/insites/2015/02/url-anatomy/url-anatomy-55598c24.png)
# L'URL est une information que l'on connait tous. C'est l'adresse dont on requiert le contenu. Typiquement, l'adresse est divisible en plusieurs parties. Celle qui peut être importante et qui changera surement suivant les utilisateurs est la partie *query* qui permet d'apporter des informations supplémentaires.
#
# Par exemple, dans http://cts.dh.uni-leipzig.de/api/cts?request=GetCapabilities&urn=urn:cts:latinLit:phi1294 , on a deux paramètres fournis :
#
# | Nom | Valeur |
# | --- | ------ |
# | urn | urn:cts:latinLit:phi1294 |
# | request | GetCapabilities |
#
# #### Méthode
#
# La méthode informe le serveur de ce que vous allez vouloir faire. 90% des requêtes que vous faites en naviguant sur le web sont en GET : vous récupérez de l'information. Vous utilisez sur les 9.9% restant la requête POST, notamment quand vous vous connectez sur vos comptes sur les divers sites que vous utilisez.
#
# #### Les Headers
#
# Le Header comporte des informations sur vos attentes et votre contexte de requêtage. Par exemple, on peut demander via les Headers un format de réponse particulier (d'après son [mimetype](https://fr.wikipedia.org/wiki/Type_MIME) : html, xml ou json par exemple :
#
# | Headers Clé | Headers Valeur   |
# | ----------- | ---------------- |
# | Accept      | application/json |
#
# #### (Optionnel) Le Corps (Body, data, etc.)
#
# Dans le cadre de l'envoi d'un formulaire ou d'un fichier, on a un corps dans la requête. Beaucoup de formats différents sont possibles dans ce cadre. De nombreuses API acceptent par exemple l'encodage en JSON de vos informations.

# %% [markdown]
# ### 1.B. Anatomie d'une réponse
#
# ![Anatomie d'une réponse HTTP](images/http.request.response.png)
#
# La réponse est composée de trois éléments aussi :
#
# #### Les Headers
#
# Tout comme la requête, les Headers nous renvoient l'information sur la réponse. Voici quelques headers utiles.
#
#
# | Headers Clé | Headers Valeur   | Note |
# | ----------- | ---------------- | ---- |
# | Encoding      | application/json | Type Mime de la réponse |
#
# #### Le code HTTP
#
# Le code HTTP nous informe sur le statut de la réponse. Vous connaissez *à minima* le code 404, qui indique que la ressource demandée n'est pas disponible. Il existe bien d'autres codes (*cf.* [Wikipedia](https://fr.wikipedia.org/wiki/Liste_des_codes_HTTP) :
# - 200 : succès de la requête ;
# - 301 et 302 : redirection, respectivement permanente et temporaire ;
# - 401 : utilisateur non authentifié ;
# - 403 : accès refusé ;
# - 404 : page non trouvée ;
# - 500 et 503 : erreur serveur.
# - 418 : "I’m a teapot" (Blague du 1er avril 1998 restée dans le standard)
#
#
#
# #### Le Corps
#
# Le corps de la réponse contient bien évidemment ce que vous voyez lorsque vous faites une requête : le contenu html, le contenu en plein texte, le contenu json, etc.

# %% [markdown]
# ## 2. Faire des requêtes http en python : le module request
#
#
# ### 2.A Le module `requests`
#
#
# Le module `requests` possède sa documentation sur son [propre site](http://docs.python-requests.org/en/master/). Au moment de l'écriture, le module est dans sa version 2.18.4.
#
# ### 2.B Faire une requête GET:
#
# Le module est très simple : il propose une fonction `get` qui prend une URL !

# %%
import requests

# Pour l'exemple nous utilisons l'API swisstopo
# Américains
req = requests.get("https://api3.geo.admin.ch/rest/services/api/MapServer")
print(req)
# Out:
# <Response [200]>

# %% [markdown]
# Les objets `Response` ont plusieurs propriétés intéressantes :
#
# - `.status_code` sous la forme d'un entier qui informe du succès de la requête
# - `.headers` sous la forme d'un dictionnaire qui comporte l'ensemble des headers
# - `.encoding` qui comprend la méthode d'encodage
# - `.text` qui contient le contenu de la réponse
# - `.json()` qui, si `.headers['content-type']` est `application/json`, parse lui-même le json de la réponse.
#
# Voyons un peu leur contenu :

# %%
print(req.status_code)
print(req.headers)
print(req.encoding)
# Out:
# 200
# {'Content-Type': 'application/json', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Access-Control-Allow-Headers': '*', 'Access-Control-Allow-Methods': 'GET, HEAD, OPTIONS', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'max-age=1800, public', 'X-Ua-Compatible': 'IE=Edge', 'Date': 'Mon, 18 Aug 2025 10:04:46 GMT', 'Server': 'Apache/2.4.59 (Debian)', 'Content-Encoding': 'gzip', 'Vary': 'accept-encoding', 'X-Cache': 'Miss from cloudfront', 'Via': '1.1 f6d3d027dc70c7291c2f685efb187ab2.cloudfront.net (CloudFront)', 'X-Amz-Cf-Pop': 'ZRH55-P1', 'X-Amz-Cf-Id': 'rVU2DswXCKbg-7f7FbzRYw1JZES1VZJvdDtmLBvKLg0igk9TgvhDaw=='}
# utf-8

# %%
req.json()  # Pour obtenir le contenu au format JSON
# Out:
# {'mapName': 'api',
#  'description': 'Configuration for the map (topic) api',
#  'copyrightUnicode': 'Data api',
#  'layers': [{'attributes': {'fullTextSearch': 'Energiestädte | Das Label Energiestadt ist ein Leistungsausweis für Gemeinden, die eine nachhaltige kommunale Energiepolitik vorleben und umsetzen. Energiestädte fördern erneuerbare Energien, umweltverträgliche Mobilität und setzen auf eine effiziente Nutzung der Ressourcen. Um das Label Energiestadt zu erreichen, muss eine Gemeinde mindestens 50% ihres energiepolitischen Handlungsspielraums, ermittelt anhand des Energiestadt-Katalogs, realisiert oder beschlossen haben. Die höchste Auszeichnung ist der «European Energy Award®GOLD». Diese Ehrung erhalten Energiestädte, die 75 Prozent oder mehr der Massnahmen des beim Zertifizierungsverfahren erstellten Katalogs umgesetzt haben. Mit dem GOLD-Award krönen Energiestädte ihr Engagement für eine nachhaltige Energiezukunft. Das Label beruht auf der Beurteilung der kommunalen Energiepolitik in Entwicklungsplanung und Raumordnung, kommunaler Gebäude und Anlagen, der Versorgung und Entsorgung, der Mobilität, der internen Organisation sowie von Kommunikation und Kooperation. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Energie BFE',
#     'inspireAbstract': 'Energiequellen',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Energiequellen',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,ech,energie,inspire,schule,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Energie BFE',
#     'urlDetails': 'https://www.bfe.admin.ch/energiestaedte',
#     'scaleLimit': "1:25'000-1'000'000",
#     'dataStatus': '20250813',
#     'inspireUpperAbstract': 'Energie und Wirtschaft',
#     'inspireUpperName': 'Energie und Wirtschaft',
#     'abstract': 'Das Label Energiestadt ist ein Leistungsausweis für Gemeinden, die eine nachhaltige kommunale Energiepolitik vorleben und umsetzen. Energiestädte fördern erneuerbare Energien, umweltverträgliche Mobilität und setzen auf eine effiziente Nutzung der Ressourcen. Um das Label Energiestadt zu erreichen, muss eine Gemeinde mindestens 50% ihres energiepolitischen Handlungsspielraums, ermittelt anhand des Energiestadt-Katalogs, realisiert oder beschlossen haben. Die höchste Auszeichnung ist der «European Energy Award®GOLD». Diese Ehrung erhalten Energiestädte, die 75 Prozent oder mehr der Massnahmen des beim Zertifizierungsverfahren erstellten Katalogs umgesetzt haben. Mit dem GOLD-Award krönen Energiestädte ihr Engagement für eine nachhaltige Energiezukunft. Das Label beruht auf der Beurteilung der kommunalen Energiepolitik in Entwicklungsplanung und Raumordnung, kommunaler Gebäude und Anlagen, der Versorgung und Entsorgung, der Mobilität, der internen Organisation sowie von Kommunikation und Kooperation.'},
#    'idGeoCat': '393940cd-6a67-4190-8b91-378669cdea1d',
#    'name': 'Energiestädte',
#    'fullName': 'Energiestädte',
#    'layerBodId': 'ch.bfe.energiestaedte'},
#   {'attributes': {'fullTextSearch': 'CadastralWebMap | Basis ist ein Darstellungsdienst (Web Map Service), der aus Daten des AV-Geoportals des Bundes kreiert wird, dessen Inhalt gegenüber den vollständigen Daten der amtlichen Vermessung (AV) jedoch reduziert ist. | swisstopo | Bundesamt für Landestopografie swisstopo | Amtliche Vermessung Schweiz, Kantone',
#     'inspireAbstract': 'Katasterparzellen',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Katasterparzellen',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,blw,cadastre,ech,energie,funksender,geol,georessourcen,inspire,isos,kgs,service-wms,swissmaponline,swisstopo',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Amtliche Vermessung Schweiz, Kantone',
#     'urlDetails': 'https://www.cadastre.ch/de/darstellungsdienst-cadastralwebmap-wms',
#     'scaleLimit': 'Min 1:500',
#     'dataStatus': '20250817',
#     'inspireUpperAbstract': 'Basisdaten',
#     'inspireUpperName': 'Basisdaten',
#     'abstract': 'Basis ist ein Darstellungsdienst (Web Map Service), der aus Daten des AV-Geoportals des Bundes kreiert wird, dessen Inhalt gegenüber den vollständigen Daten der amtlichen Vermessung (AV) jedoch reduziert ist.',
#     'urlApplication': 'https://www.cadastre.ch/de/darstellungsdienst-cadastralwebmap-wms'},
#    'idGeoCat': 'cf93dfb6-ffff-43ce-bd9b-271baba2d217',
#    'name': 'CadastralWebMap',
#    'fullName': 'CadastralWebMap',
#    'layerBodId': 'ch.kantone.cadastralwebmap-farbe'},
#   {'attributes': {'fullTextSearch': 'Kataster der belasteten Standorte im Bereich des Militärs (KbS VBS) | Sämtliche mit Abfällen belasteten Standorte, die durch das VBS verursacht wurden, werden im öffentlichen Kataster der belasteten Standorte des VBS (KbS VBS) geführt. So sind rund 550 Zielgebiete und rund 2000 belastete Betriebsstandorte, Deponien und Unfallstandorte im KbS eingetragen. Geht von diesen Belastungen eine Umweltgefährdung aus, so werden diese Standorte gemäss der Altlasten-Verordnung saniert. | Kataster der belasteten Standorte im Bereich des Militärs | swisstopo | Bundesamt für Landestopografie swisstopo | Generalsekretariat VBS',
#     'inspireAbstract': 'Umweltüberwachung',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Umweltüberwachung',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'bundCollectionNumber': '117.1',
#     'maps': 'api,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'bundCollection': 'Kataster der belasteten Standorte im Bereich des Militärs',
#     'dataOwner': 'Generalsekretariat VBS',
#     'urlDetails': 'https://www.kbs-vbs.ch/',
#     'scaleLimit': "Min. 1:1'000",
#     'dataStatus': '20250806',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/ch.vbs.kataster-belasteter-standorte-militaer/data.zip',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Sämtliche mit Abfällen belasteten Standorte, die durch das VBS verursacht wurden, werden im öffentlichen Kataster der belasteten Standorte des VBS (KbS VBS) geführt. So sind rund 550 Zielgebiete und rund 2000 belastete Betriebsstandorte, Deponien und Unfallstandorte im KbS eingetragen. Geht von diesen Belastungen eine Umweltgefährdung aus, so werden diese Standorte gemäss der Altlasten-Verordnung saniert.',
#     'urlApplication': 'https://map.geo.admin.ch'},
#    'idGeoCat': 'd56dc013-2659-4664-8829-7e097dfa4173',
#    'name': 'KbS Militär',
#    'fullName': 'Kataster der belasteten Standorte im Bereich des Militärs (KbS VBS)',
#    'layerBodId': 'ch.vbs.kataster-belasteter-standorte-militaer'},
#   {'attributes': {'fullTextSearch': 'Luftfahrthindernisdaten Schweiz | Bei den Luftfahrthindernisdaten handelt es sich um Daten gemäss Art. 2 Bst. k der Verordnung vom 23. November 1994 über die Infrastruktur der Luftfahrt (VIL; SR 748.131.1). Luftfahrthindernisse sind Bauten und Anlagen (u. a. Antennen, Gebäude, Kabel, Krane, Seilbahnen, Hochspannungsleitungen, Windenergieanlagen) sowie Pflanzen, die den Betrieb von Luftfahrzeugen oder von Flugsicherungsanlagen erschweren, gefährden oder verunmöglichen können. Sie werden im Rahmen der Bewilligungspflicht gemäss Art. 63 VIL resp. der Registrierungspflicht gemäss Art. 65a VIL erhoben. Der vorliegende Datensatz beinhaltet mit Ausnahme von Pflanzen alle permanenten und temporären Luftfahrthindernisse, wenn sie in unbebauten Gebieten eine Höhe von 25 Metern und mehr aufweisen (im Falle von Mobilkranen: 40 Meter und mehr) oder wenn sie in bebauten Gebieten eine Höhe von mindestens 60 Metern erreichen. Sicherheitsrelevante Hindernisse in der Umgebung von Flugplätzen unter 25 / 60 Metern sind im Layer "Flugplatzhindernisse < 25 / 60 m" dargestellt. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Zivilluftfahrt BAZL',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,aviation,ech,inspire,schule,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Zivilluftfahrt BAZL',
#     'urlDetails': 'https://www.bazl.admin.ch/bazl/de/home/infrastruktur/luftfahrthindernisse/luftfahrtinformationen/digitale-luftfahrthinderniskarten.html',
#     'scaleLimit': "Min. 1:5'000 - Max. 1:1'000'000",
#     'dataStatus': '20250818',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bazl.luftfahrthindernis/items/luftfahrthindernis',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Bei den Luftfahrthindernisdaten handelt es sich um Daten gemäss Art. 2 Bst. k der Verordnung vom 23. November 1994 über die Infrastruktur der Luftfahrt (VIL; SR 748.131.1). Luftfahrthindernisse sind Bauten und Anlagen (u. a. Antennen, Gebäude, Kabel, Krane, Seilbahnen, Hochspannungsleitungen, Windenergieanlagen) sowie Pflanzen, die den Betrieb von Luftfahrzeugen oder von Flugsicherungsanlagen erschweren, gefährden oder verunmöglichen können. Sie werden im Rahmen der Bewilligungspflicht gemäss Art. 63 VIL resp. der Registrierungspflicht gemäss Art. 65a VIL erhoben. Der vorliegende Datensatz beinhaltet mit Ausnahme von Pflanzen alle permanenten und temporären Luftfahrthindernisse, wenn sie in unbebauten Gebieten eine Höhe von 25 Metern und mehr aufweisen (im Falle von Mobilkranen: 40 Meter und mehr) oder wenn sie in bebauten Gebieten eine Höhe von mindestens 60 Metern erreichen. Sicherheitsrelevante Hindernisse in der Umgebung von Flugplätzen unter 25 / 60 Metern sind im Layer "Flugplatzhindernisse < 25 / 60 m" dargestellt.',
#     'urlApplication': 'https://map.geo.admin.ch/?topic=aviation&lang=de'},
#    'idGeoCat': 'b43208df-1ac2-4d00-b559-d83e4d86ba1a',
#    'name': 'Luftfahrthindernisse',
#    'fullName': 'Luftfahrthindernisdaten Schweiz',
#    'layerBodId': 'ch.bazl.luftfahrthindernis'},
#   {'attributes': {'fullTextSearch': 'Feuchtflächenpotential der offenen Kulturlandschaft, Vektor | Das Feuchtflächenpotential wurde anhand der Prozesse Wasserakkumulation und Versickerung beurteilt. Aus dem Höhenmodell (Swissalti3d © swisstopo) wurden Reliefparameter berechnet und Ebenen und Mulden modelliert. Das Potential der Versickerung wurde von Bodenkarten abgeleitet. Wo keine detaillierten Bodenkarten vorhanden waren, wurden geologische Karten und andere Surrogate in einem Expertenmodell überlagert und gewichtet. Der Vektor-Datensatz ist auf die vorwiegend landwirtschaftlich genutzten Feldblöcke zugeschnitten.Versickerung: 4 Klassen; Wasserakkumulation: 5 Klassen. Zitat: Szerencsits, E., Prasuhn, V., Churko, G., Herzog, F., Utiger, C., Zihlmann, U. et al. (2018). Karte potenzieller Feucht-Acker-Flächen der Schweiz. Agroscope Science, 72, 67. https://www.feuchtacker.ch/ | swisstopo | Bundesamt für Landestopografie swisstopo | Agroscope',
#     'inspireAbstract': 'Boden',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Boden',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Agroscope',
#     'scaleLimit': "Min 1:5'000 – Max 1:25’000",
#     'dataStatus': '20230725',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Das Feuchtflächenpotential wurde anhand der Prozesse Wasserakkumulation und Versickerung beurteilt. Aus dem Höhenmodell (Swissalti3d © swisstopo) wurden Reliefparameter berechnet und Ebenen und Mulden modelliert. Das Potential der Versickerung wurde von Bodenkarten abgeleitet. Wo keine detaillierten Bodenkarten vorhanden waren, wurden geologische Karten und andere Surrogate in einem Expertenmodell überlagert und gewichtet. Der Vektor-Datensatz ist auf die vorwiegend landwirtschaftlich genutzten Feldblöcke zugeschnitten.Versickerung: 4 Klassen; Wasserakkumulation: 5 Klassen. Zitat: Szerencsits, E., Prasuhn, V., Churko, G., Herzog, F., Utiger, C., Zihlmann, U. et al. (2018). Karte potenzieller Feucht-Acker-Flächen der Schweiz. Agroscope Science, 72, 67. https://www.feuchtacker.ch/'},
#    'idGeoCat': '5188235f-c5c3-4628-9173-055824b65539',
#    'name': 'Feuchtflächenpotential Agrarland',
#    'fullName': 'Feuchtflächenpotential der offenen Kulturlandschaft, Vektor',
#    'layerBodId': 'ch.agroscope.feuchtflaechenpotential-kulturlandschaft'},
#   {'attributes': {'fullTextSearch': 'Äschenpopulationen von nationaler Bedeutung: Larvenhabitate | Der Datensatz zu den Äschenpopulationen von nationaler Bedeutung umfasst vier Teilprodukte (Verbreitungsgebiet, Kernzonen, Laichplätze, Larvenhabitate). Der Layer Larvenhabitate enthält die Strecken, in denen Larven beobachtet wurden. die Grundlagendaten stammen aus dem Verbreitungsatlas der Fische und Rundmäuler der Schweiz (Pedroli et al. 1991), aus kantonalen Fangstatistiken sowie von Auskünften kantonaler Fischereiverwaltungen. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU',
#     'wmsContactAbbreviation': 'swisstopo',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,gewiss,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.bafu.admin.ch/bafu/de/home/themen/biodiversitaet/publikationen-studien/publikationen/aeschenpopulationen-nationale-bedeutung.html',
#     'scaleLimit': '-',
#     'dataStatus': '20110829',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.fischerei-aeschen/items/fischerei-aeschen_larvenhabitate',
#     'abstract': 'Der Datensatz zu den Äschenpopulationen von nationaler Bedeutung umfasst vier Teilprodukte (Verbreitungsgebiet, Kernzonen, Laichplätze, Larvenhabitate). Der Layer Larvenhabitate enthält die Strecken, in denen Larven beobachtet wurden. die Grundlagendaten stammen aus dem Verbreitungsatlas der Fische und Rundmäuler der Schweiz (Pedroli et al. 1991), aus kantonalen Fangstatistiken sowie von Auskünften kantonaler Fischereiverwaltungen.',
#     'urlApplication': 'http://map.bafu.admin.ch'},
#    'idGeoCat': '30c248d4-46c6-4afc-a949-d26623c8b0e6',
#    'name': 'Äschen: Larvenhabitate',
#    'fullName': 'Äschenpopulationen von nationaler Bedeutung: Larvenhabitate',
#    'layerBodId': 'ch.bafu.fischerei-aeschen_larvenhabitate'},
#   {'attributes': {'fullTextSearch': 'Alpenkonvention | Perimeter der Alpenkonvention in der Schweiz. Die Alpenkonvention ist ein völkerrechtlicher Vertrag zwischen den acht Alpenländern Deutschland, Frankreich, Italien, Liechtenstein, Monaco, Österreich, Schweiz, Slowenien sowie der Europäischen Union. Das Ziel des Übereinkommens ist der Schutz der Alpen durch eine sektorübergreifende, ganzheitliche und nachhaltige Politik. | Alpenkonvention | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Umweltüberwachung | Verwaltungseinheiten',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Umweltüberwachung | Verwaltungseinheiten',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'bundCollectionNumber': '3.1',
#     'maps': 'api,are,ech,inspire,kgs,service-wms,swissmaponline',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'bundCollection': 'Alpenkonvention',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/laendliche-raeume-und-berggebiete/internationale-zusammenarbeit/alpenkonvention.html',
#     'scaleLimit': "Min 1:25'000",
#     'dataStatus': '20090101',
#     'inspireUpperAbstract': 'Basisdaten | Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.alpenkonvention',
#     'inspireUpperName': 'Basisdaten | Umwelt, Biologie und Geologie',
#     'abstract': 'Perimeter der Alpenkonvention in der Schweiz. Die Alpenkonvention ist ein völkerrechtlicher Vertrag zwischen den acht Alpenländern Deutschland, Frankreich, Italien, Liechtenstein, Monaco, Österreich, Schweiz, Slowenien sowie der Europäischen Union. Das Ziel des Übereinkommens ist der Schutz der Alpen durch eine sektorübergreifende, ganzheitliche und nachhaltige Politik.',
#     'urlApplication': 'http://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.alpenkonvention&layers_opacity=0.2&layers_visibility=true&lang=de'},
#    'idGeoCat': '8698bf0b-fceb-4f0f-989b-111e7c4af0a4',
#    'name': 'Alpenkonvention',
#    'fullName': 'Alpenkonvention',
#    'layerBodId': 'ch.are.alpenkonvention'},
#   {'attributes': {'fullTextSearch': 'Bauzonen Schweiz (harmonisiert) | Der Datensatz „Bauzonen Schweiz (harmonisiert)“ basiert auf den bei den kantonalen Fachstellen für Raumplanung am 1.1.2022 verfügbaren Geodaten zu den Bauzonen. Die kantonalen Zonentypen wurden gemäss dem minimalen Geodatenmodell Nutzungsplanung den neun Hauptnutzungen innerhalb der Bauzonen zugeordnet. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE, Kantone',
#     'inspireAbstract': 'Bodennutzung | Katasterparzellen',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Bodennutzung | Katasterparzellen',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,georessourcen,inspire,kgs,service-wms,swissmaponline',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE, Kantone',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/raumentwicklung-und-raumplanung/grundlagen-und-daten/bauzonenstatistik-schweiz.html',
#     'scaleLimit': '-',
#     'dataStatus': '20220101',
#     'inspireUpperAbstract': 'Basisdaten | Energie und Wirtschaft',
#     'downloadUrl': 'https://www.kgk-cgc.ch/geodaten/geodaten-bauzonen-schweiz',
#     'inspireUpperName': 'Basisdaten | Energie und Wirtschaft',
#     'abstract': 'Der Datensatz „Bauzonen Schweiz (harmonisiert)“ basiert auf den bei den kantonalen Fachstellen für Raumplanung am 1.1.2022 verfügbaren Geodaten zu den Bauzonen. Die kantonalen Zonentypen wurden gemäss dem minimalen Geodatenmodell Nutzungsplanung den neun Hauptnutzungen innerhalb der Bauzonen zugeordnet.',
#     'urlApplication': 'http://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.bauzonen&layers_opacity=0.6&layers_visibility=true&lang=de'},
#    'idGeoCat': '055192b1-c378-4e66-8d43-c926f0be7980',
#    'name': 'Bauzonen Schweiz (harmonisiert)',
#    'fullName': 'Bauzonen Schweiz (harmonisiert)',
#    'layerBodId': 'ch.are.bauzonen'},
#   {'attributes': {'fullTextSearch': 'swissEO VHI: Gesundheitszustand des Waldes | Karte des Waldzustandes basierend auf dem VHI (Vegetation Health Index), der den aktuellen Zustand des Waldes im Verhältnis zu historischen Daten 1991-2020 abbildet. Der Index basiert auf Satellitendaten (Meteosat, Landsat 5,7,8 und Sentinel-2) unterschiedlicher räumlicher Auflösung zusammengefasst in einer aggregierten Auflösung von zehn respektive dreissig Metern. Der VHI setzt sich aus zwei Komponenten zusammen: der eine Teil (VCI - Vegetation Condition Index) bildet die lokalen biophysikalischen Gegebenheiten der Vegetation ab und der andere Teil (TCI - Thermal Condition Index) charakterisiert die klimatischen Bedingungen (Temperatur). Beide Teile stellen die aktuelle Situation im Verhältnis zu einer Referenzperiode dar. Kombiniert wird der VHI für die Beurteilung von Trockenheit und anderen Störungen oder Stressfaktoren benutzt - je tiefer der Wert, desto stärker der Stress und dessen Auswirkung auf die Vegetation. Werte von 100 runter auf 60 stehen für einen exzellenten Vegetationszustand, Werte bis 50 sind gut, Werte bis 40 normal einzuordnen. Unter 40 zeigt die Vegetation Stresssymptome, ist bis 30 leicht gestresst, bis 20 gestresst, bis 10 sehr gestresst und Werte unter 10 weisen einen extrem gestressten Vegetationszustand auf. In der Kartendarstellung wird die Waldfläche gezeigt, die einen robusten Indikator für den regionalen Vegetationszustand liefert. Der Datensatz wurde in Zusammenarbeit mit MeteoSchweiz für das Trockenheitsportal des Bundes entwickelt.Enthält geänderte Copernicus Sentinel-Daten. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Landestopografie swisstopo',
#     'inspireAbstract': 'Umweltüberwachung',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Umweltüberwachung',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,ech,inspire,service-wms,swisstopo',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Landestopografie swisstopo',
#     'urlDetails': 'https://www.swisstopo.admin.ch/de/satellitenbilder-swisseo',
#     'scaleLimit': "1:20'000",
#     'dataStatus': '20250814 23:59 UTC',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.swisstopo.swisseo_vhi_v100',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Karte des Waldzustandes basierend auf dem VHI (Vegetation Health Index), der den aktuellen Zustand des Waldes im Verhältnis zu historischen Daten 1991-2020 abbildet. Der Index basiert auf Satellitendaten (Meteosat, Landsat 5,7,8 und Sentinel-2) unterschiedlicher räumlicher Auflösung zusammengefasst in einer aggregierten Auflösung von zehn respektive dreissig Metern. Der VHI setzt sich aus zwei Komponenten zusammen: der eine Teil (VCI - Vegetation Condition Index) bildet die lokalen biophysikalischen Gegebenheiten der Vegetation ab und der andere Teil (TCI - Thermal Condition Index) charakterisiert die klimatischen Bedingungen (Temperatur). Beide Teile stellen die aktuelle Situation im Verhältnis zu einer Referenzperiode dar. Kombiniert wird der VHI für die Beurteilung von Trockenheit und anderen Störungen oder Stressfaktoren benutzt - je tiefer der Wert, desto stärker der Stress und dessen Auswirkung auf die Vegetation. Werte von 100 runter auf 60 stehen für einen exzellenten Vegetationszustand, Werte bis 50 sind gut, Werte bis 40 normal einzuordnen. Unter 40 zeigt die Vegetation Stresssymptome, ist bis 30 leicht gestresst, bis 20 gestresst, bis 10 sehr gestresst und Werte unter 10 weisen einen extrem gestressten Vegetationszustand auf. In der Kartendarstellung wird die Waldfläche gezeigt, die einen robusten Indikator für den regionalen Vegetationszustand liefert. Der Datensatz wurde in Zusammenarbeit mit MeteoSchweiz für das Trockenheitsportal des Bundes entwickelt.Enthält geänderte Copernicus Sentinel-Daten.'},
#    'idGeoCat': 'bc4d0e6b-e92e-4f28-a7d2-f41bf61e98bc',
#    'name': 'swissEO VHI Wald',
#    'fullName': 'swissEO VHI: Gesundheitszustand des Waldes',
#    'layerBodId': 'ch.swisstopo.swisseo_vhi_v100'},
#   {'attributes': {'fullTextSearch': 'Waldbrandpräventionsmassnahmen der Kantone | Enthält die aktuell bestehenden Präventionsmassnahmen der Kantone zur Waldbrandgefahr | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU, Kantone',
#     'inspireAbstract': 'Gebiete mit naturbedingten Risiken',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Gebiete mit naturbedingten Risiken',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,inspire,kgs,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU, Kantone',
#     'urlDetails': 'https://www.waldbrandgefahr.ch/',
#     'scaleLimit': '',
#     'dataStatus': '20250818 10:01',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.gefahren-waldbrand_praeventionsmassnahmen_kantone',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Enthält die aktuell bestehenden Präventionsmassnahmen der Kantone zur Waldbrandgefahr',
#     'urlApplication': 'http://map.bafu.admin.ch'},
#    'idGeoCat': '5deca805-ace4-4401-9750-cb1b02f5a292',
#    'name': 'Waldbrandpräventionsmassnahmen',
#    'fullName': 'Waldbrandpräventionsmassnahmen der Kantone',
#    'layerBodId': 'ch.bafu.gefahren-waldbrand_praeventionsmassnahmen_kantone'},
#   {'attributes': {'fullTextSearch': 'Belastung (Personen) des schweizerischen Schienennetzes (Personenverkehr) 2050 | Beförderte Personen im öffentlichen Verkehr auf dem schweizerischen Schienennetz (inkl. Tram) im Jahr 2050. Tageswerte für den durchschnittlichen Werktagverkehr (DWV) und den durchschnittlichen Tagesverkehr (DTV) sowie Werte der Morgenspitze (7h-8h, MSP) und der Abendspitze (17h-18h, ASP). Quelle: Verkehrsperspektiven 2050, Szenario Basis. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/mobilitaet/grundlagen-und-daten/verkehrsperspektiven.html',
#     'scaleLimit': '',
#     'dataStatus': '20210630',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.belastung-personenverkehr-bahn_zukunft',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Beförderte Personen im öffentlichen Verkehr auf dem schweizerischen Schienennetz (inkl. Tram) im Jahr 2050. Tageswerte für den durchschnittlichen Werktagverkehr (DWV) und den durchschnittlichen Tagesverkehr (DTV) sowie Werte der Morgenspitze (7h-8h, MSP) und der Abendspitze (17h-18h, ASP). Quelle: Verkehrsperspektiven 2050, Szenario Basis.',
#     'urlApplication': 'http://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.belastung-personenverkehr-bahn-2050&layers_opacity=1&layers_visibility=true&lang=de'},
#    'idGeoCat': '8f947ac4-0334-4065-a55f-2563b39cd6ed',
#    'name': 'Personenverkehr Schiene 2050',
#    'fullName': 'Belastung (Personen) des schweizerischen Schienennetzes (Personenverkehr) 2050',
#    'layerBodId': 'ch.are.belastung-personenverkehr-bahn_zukunft'},
#   {'attributes': {'fullTextSearch': 'Äschenpopulationen von nationaler Bedeutung: Laichplätze | Der Datensatz zu den Äschenpopulationen von nationaler Bedeutung umfasst vier Teilprodukte (Verbreitungsgebiete, Kernzonen, Laichplätze, Larvenhabitate). Der Layer Laichplätze enthält die Strecken in denen natürliche Reproduktion stattfindet. Die Grundlagendaten stammen aus dem Verbreitungsatlas der Fische und Rundmäuler der Schweiz (Pedroli et al. 1991), aus kantonalen Fangstatistiken sowie von Auskünften kantonaler Fischereiverwaltungen. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU',
#     'wmsContactAbbreviation': 'swisstopo',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,gewiss,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.bafu.admin.ch/bafu/de/home/zustand/daten/geodaten/biodiversitaet--geodaten.html#-184504727',
#     'scaleLimit': '-',
#     'dataStatus': '20110829',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.fischerei-aeschen/items/fischerei-aeschen_laichplaetze',
#     'abstract': 'Der Datensatz zu den Äschenpopulationen von nationaler Bedeutung umfasst vier Teilprodukte (Verbreitungsgebiete, Kernzonen, Laichplätze, Larvenhabitate). Der Layer Laichplätze enthält die Strecken in denen natürliche Reproduktion stattfindet. Die Grundlagendaten stammen aus dem Verbreitungsatlas der Fische und Rundmäuler der Schweiz (Pedroli et al. 1991), aus kantonalen Fangstatistiken sowie von Auskünften kantonaler Fischereiverwaltungen.',
#     'urlApplication': 'http://map.bafu.admin.ch'},
#    'idGeoCat': '53c8a8bb-67ab-4525-8b64-011079e63294',
#    'name': 'Äschen: Laichplätze',
#    'fullName': 'Äschenpopulationen von nationaler Bedeutung: Laichplätze',
#    'layerBodId': 'ch.bafu.fischerei-aeschen_laichplaetze'},
#   {'attributes': {'fullTextSearch': 'Belastung (Fahrzeuge) des schweizerischen Strassennetzes nach Fahrzeugkategorien (Personen- und Güterverkehr) 2050 | Fahrzeuge auf dem schweizerischen Strassennetz unterschieden nach Personenwagen (PW), Lieferwagen (LI), Lastwagen (LW) und Lastzügen (LZ) im Jahr 2050. Tageswerte für den durchschnittlichen Werktagverkehr (DWV) und den durchschnittlichen Tagesverkehr (DTV) sowie Werte der Morgenspitze (7h-8h, MSP) und der Abendspitze (17h-18h, ASP). Quelle: Verkehrsperspektiven 2050, Szenario Basis. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/mobilitaet/grundlagen-und-daten/verkehrsperspektiven.html',
#     'scaleLimit': '',
#     'dataStatus': '20210630',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.belastung-personenverkehr-strasse_zukunft',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Fahrzeuge auf dem schweizerischen Strassennetz unterschieden nach Personenwagen (PW), Lieferwagen (LI), Lastwagen (LW) und Lastzügen (LZ) im Jahr 2050. Tageswerte für den durchschnittlichen Werktagverkehr (DWV) und den durchschnittlichen Tagesverkehr (DTV) sowie Werte der Morgenspitze (7h-8h, MSP) und der Abendspitze (17h-18h, ASP). Quelle: Verkehrsperspektiven 2050, Szenario Basis.',
#     'urlApplication': 'http://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.belastung-personenverkehr-strasse-2050&layers_opacity=1&layers_visibility=true&lang=de'},
#    'idGeoCat': '5cd6d93e-3fbc-4ce9-b32b-136affb6baca',
#    'name': 'Personen-/Güterverkehr Strasse 2050',
#    'fullName': 'Belastung (Fahrzeuge) des schweizerischen Strassennetzes nach Fahrzeugkategorien (Personen- und Güterverkehr) 2050',
#    'layerBodId': 'ch.are.belastung-personenverkehr-strasse_zukunft'},
#   {'attributes': {'fullTextSearch': 'Erreichbarkeit auf der Strasse in Abhängigkeit von Reisezeit und Potenzial am Ziel | Erreichbarkeit je Verkehrszone auf der Strasse in Abhängigkeit der Reisezeiten von allen Zonen in der Schweiz zur Verkehrszone sowie der Anzahl von in der Verkehrszone vorhandenen Einwohnern und Arbeitsplätzen. Quelle: Nationales Personenverkehrsmodell (NPVM) des UVEK. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/verkehr-und-infrastruktur/grundlagen-und-daten/verkehrsmodellierung/npvm.html',
#     'scaleLimit': '',
#     'dataStatus': '20170630',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.erreichbarkeit-miv',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Erreichbarkeit je Verkehrszone auf der Strasse in Abhängigkeit der Reisezeiten von allen Zonen in der Schweiz zur Verkehrszone sowie der Anzahl von in der Verkehrszone vorhandenen Einwohnern und Arbeitsplätzen. Quelle: Nationales Personenverkehrsmodell (NPVM) des UVEK.',
#     'urlApplication': 'https://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.erreichbarkeit-miv&layers_opacity=0.75&layers_visibility=true&lang=de'},
#    'idGeoCat': 'f0835478-07fc-4e12-bf48-51646a59c809',
#    'name': 'Erreichbarkeit auf der Strasse',
#    'fullName': 'Erreichbarkeit auf der Strasse in Abhängigkeit von Reisezeit und Potenzial am Ziel',
#    'layerBodId': 'ch.are.erreichbarkeit-miv'},
#   {'attributes': {'fullTextSearch': 'Erreichbarkeit mit dem öffentlichen Verkehr in Abhängigkeit von Reisezeit und Potenzial am Ziel | Erreichbarkeit je Verkehrszone im ÖV in Abhängigkeit der ÖV-Reisezeiten von allen Zonen in der Schweiz zur Verkehrszone sowie der Anzahl von in der Verkehrszone vorhandenen Einwohnern und Arbeitsplätzen. Quelle: Nationales Personenverkehrsmodell (NPVM) des UVEK. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://www.are.admin.ch/are/de/home/verkehr-und-infrastruktur/grundlagen-und-daten/verkehrsmodellierung/npvm.html',
#     'scaleLimit': '',
#     'dataStatus': '20170630',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.erreichbarkeit-oev',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Erreichbarkeit je Verkehrszone im ÖV in Abhängigkeit der ÖV-Reisezeiten von allen Zonen in der Schweiz zur Verkehrszone sowie der Anzahl von in der Verkehrszone vorhandenen Einwohnern und Arbeitsplätzen. Quelle: Nationales Personenverkehrsmodell (NPVM) des UVEK.',
#     'urlApplication': 'https://map.are.admin.ch/?Y=660000&X=190000&zoom=1&bgLayer=ch.swisstopo.pixelkarte-grau&layers=ch.are.erreichbarkeit-oev&layers_opacity=0.75&layers_visibility=true&lang=de'},
#    'idGeoCat': 'e3437f64-68e1-4b07-ae35-22597ca89cc2',
#    'name': 'Erreichbarkeit mit dem ÖV',
#    'fullName': 'Erreichbarkeit mit dem öffentlichen Verkehr in Abhängigkeit von Reisezeit und Potenzial am Ziel',
#    'layerBodId': 'ch.are.erreichbarkeit-oev'},
#   {'attributes': {'fullTextSearch': 'Haltestellen des öffentlichen Verkehrs | Der Geobasisdatensatz "Haltestellen des öffentlichen Verkehrs" umfasst die Haltestellen des öffentlichen Verkehrs der Schweiz sowie weitere punktuelle, räumlich lokalisierbare Orte des öffentlichen Verkehrs, die eine betriebliche oder strukturbildende Bedeutung haben (Betriebspunkte). | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Verkehr BAV',
#     'inspireAbstract': 'Verkehrsnetze',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Verkehrsnetze',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'bundCollectionNumber': '98.2',
#     'maps': 'api,bav,ech,inspire,kgs,schneesport,schule,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Verkehr BAV',
#     'urlDetails': 'https://www.bav.admin.ch/bav/de/home/allgemeine-themen/fachthemen/geoinformation/geobasisdaten/haltestellen-des-oeffentlichen-verkehrs.html',
#     'scaleLimit': '1:10000 - 1:100000',
#     'dataStatus': '20250817',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/ch.bav.haltestellen-oev/data.zip',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Der Geobasisdatensatz "Haltestellen des öffentlichen Verkehrs" umfasst die Haltestellen des öffentlichen Verkehrs der Schweiz sowie weitere punktuelle, räumlich lokalisierbare Orte des öffentlichen Verkehrs, die eine betriebliche oder strukturbildende Bedeutung haben (Betriebspunkte).',
#     'urlApplication': 'https://www.bav.admin.ch/bav/de/home/allgemeine-themen/fachthemen/vollzugshilfen/verzeichnisse.html'},
#    'idGeoCat': '841d42ff-8177-4e07-a96b-e8e5455ae048',
#    'name': 'öV-Haltestellen',
#    'fullName': 'Haltestellen des öffentlichen Verkehrs',
#    'layerBodId': 'ch.bav.haltestellen-oev'},
#   {'attributes': {'fullTextSearch': 'Landwirtschaftliche Zonengrenzen der Schweiz | Der Geobasisdatensatz der landwirtschaftlichen Zonen und Gebiete besteht aus sechs landwirtschaftlichen Produktionszonen und dem Sömmerungsgebiet und bildet den landwirtschaftlichen Produktionskataster. Der landwirtschaftliche Produktionskataster erfasst erschwerende Produktionsverhältnisse und Lebensbedingungen, die bei der Anwendung des Landwirtschaftsgesetzes angemessen zu berücksichtigen sind. Die Rechtsgrundlagen sind in Artikel 4 des Landwirtschaftsgesetzes (SR 910.1) sowie in der Verordnung über den landwirtschaftlichen Produktionskataster und die Ausscheidung von Zonen (SR 912.1) geregelt. Verschiedene Massnahmen im Bereich des Landwirtschaftsgesetzes sind auf die Zoneneinteilung abgestützt. Ein Teil der Direktzahlungen an die Landwirtschaft beispielsweise wird differenziert nach Zonenzugehörigkeit ausgerichtet. | Landwirtschaftliche Zonengrenzen der Schweiz | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Landwirtschaft BLW',
#     'inspireAbstract': 'Bodennutzung | Geregelte Gebiete und Berichterstattungseinheiten',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Bodennutzung | Geregelte Gebiete und Berichterstattungseinheiten',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'bundCollectionNumber': '149.1',
#     'maps': 'api,blw,ech,inspire,schule,service-wms,swissmaponline',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'bundCollection': 'Landwirtschaftliche Zonengrenzen der Schweiz',
#     'dataOwner': 'Bundesamt für Landwirtschaft BLW',
#     'urlDetails': 'https://www.blw.admin.ch/blw/de/home/instrumente/grundlagen-und-querschnittsthemen/landwirtschaftliche-zonen.html',
#     'scaleLimit': "Min 1:25'000",
#     'dataStatus': '20250805',
#     'inspireUpperAbstract': 'Energie und Wirtschaft | Raum und Bevölkerung',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.blw.landwirtschaftliche-zonengrenzen',
#     'inspireUpperName': 'Energie und Wirtschaft | Raum und Bevölkerung',
#     'abstract': 'Der Geobasisdatensatz der landwirtschaftlichen Zonen und Gebiete besteht aus sechs landwirtschaftlichen Produktionszonen und dem Sömmerungsgebiet und bildet den landwirtschaftlichen Produktionskataster. Der landwirtschaftliche Produktionskataster erfasst erschwerende Produktionsverhältnisse und Lebensbedingungen, die bei der Anwendung des Landwirtschaftsgesetzes angemessen zu berücksichtigen sind. Die Rechtsgrundlagen sind in Artikel 4 des Landwirtschaftsgesetzes (SR 910.1) sowie in der Verordnung über den landwirtschaftlichen Produktionskataster und die Ausscheidung von Zonen (SR 912.1) geregelt. Verschiedene Massnahmen im Bereich des Landwirtschaftsgesetzes sind auf die Zoneneinteilung abgestützt. Ein Teil der Direktzahlungen an die Landwirtschaft beispielsweise wird differenziert nach Zonenzugehörigkeit ausgerichtet.',
#     'urlApplication': 'http://map.blw.admin.ch/'},
#    'idGeoCat': '6e4544bc-55f4-4aef-b36a-e36fe376eaf8',
#    'name': 'Landwirtschaftliche Zonengrenzen',
#    'fullName': 'Landwirtschaftliche Zonengrenzen der Schweiz',
#    'layerBodId': 'ch.blw.landwirtschaftliche-zonengrenzen'},
#   {'attributes': {'fullTextSearch': 'Siedlung | Die «Siedlung» ist ein Geodatensatz der besiedelten Landschaft aus Sicht der Raumentwicklung. Der Datensatz dient als geometrische Referenz für verschiedene Indikatoren in der Raumbeobachtung. Als besiedelt gilt, was zu Wohn-, Arbeits- oder Freizeitzwecken bebaut wurde. Dazu gehören, insbesondere die Gebäude inklusive Umschwung sowie angrenzende Strassen und Verkehrsinfrastrukturen zu deren unmittelbaren Erschliessung. Lücken, welche mehr als 1500 m2 umfassen, bleiben als solche bestehen. Die Datenebene basiert auf Daten des topografischen Landschaftsmodells von swisstopo und des Gebäude- und Wohnungsregisters des BFS.Die Daten werden jährlich aktualisiert und publiziert. Zurzeit können die Zeitstände von 2019 bis 2024 können auf map.geo.admich.ch als Zeitreise betrachtet werden und auf https://data.geo.admin.ch/browser/index.html#/collections/ch.are.siedlung als Jahresstände heruntergeladen werden. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Raumentwicklung ARE',
#     'inspireAbstract': 'Bodennutzung',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Bodennutzung',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,are,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Raumentwicklung ARE',
#     'urlDetails': 'https://data.geo.admin.ch/ch.are.siedlung/siedlung.zip',
#     'scaleLimit': "1:10'000",
#     'dataStatus': '20250124',
#     'inspireUpperAbstract': 'Energie und Wirtschaft',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.are.siedlung',
#     'inspireUpperName': 'Energie und Wirtschaft',
#     'abstract': 'Die «Siedlung» ist ein Geodatensatz der besiedelten Landschaft aus Sicht der Raumentwicklung. Der Datensatz dient als geometrische Referenz für verschiedene Indikatoren in der Raumbeobachtung. Als besiedelt gilt, was zu Wohn-, Arbeits- oder Freizeitzwecken bebaut wurde. Dazu gehören, insbesondere die Gebäude inklusive Umschwung sowie angrenzende Strassen und Verkehrsinfrastrukturen zu deren unmittelbaren Erschliessung. Lücken, welche mehr als 1500 m2 umfassen, bleiben als solche bestehen. Die Datenebene basiert auf Daten des topografischen Landschaftsmodells von swisstopo und des Gebäude- und Wohnungsregisters des BFS.Die Daten werden jährlich aktualisiert und publiziert. Zurzeit können die Zeitstände von 2019 bis 2024 können auf map.geo.admich.ch als Zeitreise betrachtet werden und auf https://data.geo.admin.ch/browser/index.html#/collections/ch.are.siedlung als Jahresstände heruntergeladen werden.',
#     'urlApplication': 'https://map.geo.admin.ch/?topic=are&lang=de'},
#    'idGeoCat': '4229c353-e780-42d8-9f8c-298c83920a3a',
#    'name': 'Siedlung',
#    'fullName': 'Siedlung',
#    'layerBodId': 'ch.are.siedlung'},
#   {'attributes': {'fullTextSearch': 'Notfalltreffpunkte (NTP) | Notfalltreffpunkte sind die erste Anlaufstelle für die Bevölkerung bei Katastrophen, Notlagen und schweren Mangellagen, bei der die Bevölkerung im Ereignisfall Unterstützung und Informationen über die aktuelle Lage erhält. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Bevölkerungsschutz BABS',
#     'inspireAbstract': 'Versorgungswirtschaft und staatliche Dienste',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Versorgungswirtschaft und staatliche Dienste',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,ech,inspire,kgs,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Bevölkerungsschutz BABS',
#     'urlDetails': 'https://www.babs.admin.ch/de/ntp',
#     'scaleLimit': '',
#     'dataStatus': '20250815',
#     'inspireUpperAbstract': 'Infrastruktur und Kommunikation',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.babs.notfalltreffpunkte/items/notfalltreffpunkte',
#     'inspireUpperName': 'Infrastruktur und Kommunikation',
#     'abstract': 'Notfalltreffpunkte sind die erste Anlaufstelle für die Bevölkerung bei Katastrophen, Notlagen und schweren Mangellagen, bei der die Bevölkerung im Ereignisfall Unterstützung und Informationen über die aktuelle Lage erhält.'},
#    'idGeoCat': 'ed3039e3-6437-4be9-8c99-a3111da201ab',
#    'name': 'Notfalltreffpunkte NTP',
#    'fullName': 'Notfalltreffpunkte (NTP)',
#    'layerBodId': 'ch.babs.notfalltreffpunkte'},
#   {'attributes': {'fullTextSearch': 'Amtliches Verzeichnis der Gebäudeadressen | Offizieller Datensatz für «Amtliches Verzeichnis der Gebäudeadressen», ID197, gemäss Katalog der Geobasisdaten nach Bundesrecht. Das amtliche Verzeichnis der Gebäudeadressen beinhaltet sämtliche offiziellen und damit behördenverbindlichen Gebäudeadressen der Schweiz. Alle Gebäude müssen eine oder mehrere eindeutige Adressen aufweisen. Gebäude mit Wohnnutzung, Arbeitsstätten sowie Gebäude von allgemein öffentlichem Interesse müssen zwingend im amtlichen Verzeichnis der Gebäudeadressen erscheinen.Es handelt sich um eine Collection, die sowohl Zugriff auf die Gebäudeadressen der Schweiz als auch Liechtensteins bietet. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Landestopografie swisstopo',
#     'inspireAbstract': 'Adressen',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Adressen',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'bundCollectionNumber': '197.1',
#     'maps': 'api,cadastre,ech,inspire,kgs,service-wms,swisstopo',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Landestopografie swisstopo',
#     'urlDetails': 'https://www.swisstopo.admin.ch/de/amtliches-verzeichnis-der-gebaeudeadressen',
#     'scaleLimit': '',
#     'dataStatus': '20250818',
#     'inspireUpperAbstract': 'Basisdaten',
#     'downloadUrl': 'https://www.swisstopo.admin.ch/de/amtliches-verzeichnis-der-gebaeudeadressen',
#     'inspireUpperName': 'Basisdaten',
#     'abstract': 'Offizieller Datensatz für «Amtliches Verzeichnis der Gebäudeadressen», ID197, gemäss Katalog der Geobasisdaten nach Bundesrecht. Das amtliche Verzeichnis der Gebäudeadressen beinhaltet sämtliche offiziellen und damit behördenverbindlichen Gebäudeadressen der Schweiz. Alle Gebäude müssen eine oder mehrere eindeutige Adressen aufweisen. Gebäude mit Wohnnutzung, Arbeitsstätten sowie Gebäude von allgemein öffentlichem Interesse müssen zwingend im amtlichen Verzeichnis der Gebäudeadressen erscheinen.Es handelt sich um eine Collection, die sowohl Zugriff auf die Gebäudeadressen der Schweiz als auch Liechtensteins bietet.',
#     'urlApplication': 'https://www.swisstopo.admin.ch/de/amtliches-verzeichnis-der-gebaeudeadressen'},
#    'idGeoCat': '150c38c5-2650-4018-b5c7-939e2cdd56ce',
#    'name': 'Amtliches Gebäudeadressverzeichnis',
#    'fullName': 'Amtliches Verzeichnis der Gebäudeadressen',
#    'layerBodId': 'ch.swisstopo.amtliches-gebaeudeadressverzeichnis'},
# ...
#     'inspireAbstract': 'Boden',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Boden',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.tandfonline.com/doi/full/10.1080/17445647.2019.1585980',
#     'scaleLimit': '',
#     'dataStatus': '20190401',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.erosion-gruenland_bodenabtrag/items/erosion-gruenland_bodenabtrag_dez',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Monatliche Erosionsrisikokarten für das Schweizer Dauergrünland mit einer räumlichen Auflösung von 100 m. Die Karten zeigen den mittleren Bodenabtrag in Tonnen pro Hektare und Monat. Grüne Farbtöne bedeuten ein geringes, gelbe ein mittleres und rote ein hohes Erosionsrisiko.Die monatlichen Erosionsrisikokarten wurden mit der Revised Universal Soil Loss Equation (RUSLE) gerechnet. Für diese RUSLE-Anwendung wurde die monatliche Dynamik der Faktoren Niederschlagserosivität (R-Faktor) und Bodenbedeckung (C-Faktor) wie folgt berücksichtigt: A(Monat)=R(Monat)*K*C(Monat)*L*S*P wobei A(Monat) der Bodenabtrag in Tonnen pro Hektare und Monat und R(Monat) und C(Monat) der monatliche R-Faktor (MJ mm ha⁻¹ h⁻¹ Monat⁻¹) und C-Faktor (dimensionslos) sind. Die weiteren Erosionsfaktoren sind die Bodenerodierbarkeit (K-Faktor), die Hanglänge (L-Faktor) und die Hangneigung (S-Faktor) sowie Schutzmassnahmen (P-Faktor). Die RUSLE-Faktoren wurden an die besonderen Umweltbedingungen des Schweizer Dauergrünlands angepasst. Der P-Faktor ist als Konstante mit dem Wert 1 in die Berechnung eingeflossen, da räumliche Daten zum Weidemanagement und dessen Einfluss auf die Bodenerosion fehlen.',
#     'urlApplication': 'https://map.bafu.admin.ch'},
#    'idGeoCat': 'b7a8ae3e-5ce7-429e-9783-4c4cd02481b9',
#    'name': 'Erosionsrisiko Dauergrünland Dez.',
#    'fullName': 'Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Dezember',
#    'layerBodId': 'ch.bafu.erosion-gruenland_bodenabtrag_dez'},
#   {'attributes': {'fullTextSearch': 'Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), August | Monatliche Erosionsrisikokarten für das Schweizer Dauergrünland mit einer räumlichen Auflösung von 100 m. Die Karten zeigen den mittleren Bodenabtrag in Tonnen pro Hektare und Monat. Grüne Farbtöne bedeuten ein geringes, gelbe ein mittleres und rote ein hohes Erosionsrisiko.Die monatlichen Erosionsrisikokarten wurden mit der Revised Universal Soil Loss Equation (RUSLE) gerechnet. Für diese RUSLE-Anwendung wurde die monatliche Dynamik der Faktoren Niederschlagserosivität (R-Faktor) und Bodenbedeckung (C-Faktor) wie folgt berücksichtigt: A(Monat)=R(Monat)*K*C(Monat)*L*S*P wobei A(Monat) der Bodenabtrag in Tonnen pro Hektare und Monat und R(Monat) und C(Monat) der monatliche R-Faktor (MJ mm ha⁻¹ h⁻¹ Monat⁻¹) und C-Faktor (dimensionslos) sind. Die weiteren Erosionsfaktoren sind die Bodenerodierbarkeit (K-Faktor), die Hanglänge (L-Faktor) und die Hangneigung (S-Faktor) sowie Schutzmassnahmen (P-Faktor). Die RUSLE-Faktoren wurden an die besonderen Umweltbedingungen des Schweizer Dauergrünlands angepasst. Der P-Faktor ist als Konstante mit dem Wert 1 in die Berechnung eingeflossen, da räumliche Daten zum Weidemanagement und dessen Einfluss auf die Bodenerosion fehlen. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU',
#     'inspireAbstract': 'Boden',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Boden',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.tandfonline.com/doi/full/10.1080/17445647.2019.1585980',
#     'scaleLimit': '',
#     'dataStatus': '20190401',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.erosion-gruenland_bodenabtrag/items/erosion-gruenland_bodenabtrag_aug',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Monatliche Erosionsrisikokarten für das Schweizer Dauergrünland mit einer räumlichen Auflösung von 100 m. Die Karten zeigen den mittleren Bodenabtrag in Tonnen pro Hektare und Monat. Grüne Farbtöne bedeuten ein geringes, gelbe ein mittleres und rote ein hohes Erosionsrisiko.Die monatlichen Erosionsrisikokarten wurden mit der Revised Universal Soil Loss Equation (RUSLE) gerechnet. Für diese RUSLE-Anwendung wurde die monatliche Dynamik der Faktoren Niederschlagserosivität (R-Faktor) und Bodenbedeckung (C-Faktor) wie folgt berücksichtigt: A(Monat)=R(Monat)*K*C(Monat)*L*S*P wobei A(Monat) der Bodenabtrag in Tonnen pro Hektare und Monat und R(Monat) und C(Monat) der monatliche R-Faktor (MJ mm ha⁻¹ h⁻¹ Monat⁻¹) und C-Faktor (dimensionslos) sind. Die weiteren Erosionsfaktoren sind die Bodenerodierbarkeit (K-Faktor), die Hanglänge (L-Faktor) und die Hangneigung (S-Faktor) sowie Schutzmassnahmen (P-Faktor). Die RUSLE-Faktoren wurden an die besonderen Umweltbedingungen des Schweizer Dauergrünlands angepasst. Der P-Faktor ist als Konstante mit dem Wert 1 in die Berechnung eingeflossen, da räumliche Daten zum Weidemanagement und dessen Einfluss auf die Bodenerosion fehlen.',
#     'urlApplication': 'https://map.bafu.admin.ch'},
#    'idGeoCat': '6672872c-a579-42e1-b7d4-35d706b61cfb',
#    'name': 'Erosionsrisiko Dauergrünland Aug.',
#    'fullName': 'Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), August',
#    'layerBodId': 'ch.bafu.erosion-gruenland_bodenabtrag_aug'},
#   {'attributes': {'fullTextSearch': 'Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), April | Monatliche Erosionsrisikokarten für das Schweizer Dauergrünland mit einer räumlichen Auflösung von 100 m. Die Karten zeigen den mittleren Bodenabtrag in Tonnen pro Hektare und Monat. Grüne Farbtöne bedeuten ein geringes, gelbe ein mittleres und rote ein hohes Erosionsrisiko.Die monatlichen Erosionsrisikokarten wurden mit der Revised Universal Soil Loss Equation (RUSLE) gerechnet. Für diese RUSLE-Anwendung wurde die monatliche Dynamik der Faktoren Niederschlagserosivität (R-Faktor) und Bodenbedeckung (C-Faktor) wie folgt berücksichtigt: A(Monat)=R(Monat)*K*C(Monat)*L*S*P wobei A(Monat) der Bodenabtrag in Tonnen pro Hektare und Monat und R(Monat) und C(Monat) der monatliche R-Faktor (MJ mm ha⁻¹ h⁻¹ Monat⁻¹) und C-Faktor (dimensionslos) sind. Die weiteren Erosionsfaktoren sind die Bodenerodierbarkeit (K-Faktor), die Hanglänge (L-Faktor) und die Hangneigung (S-Faktor) sowie Schutzmassnahmen (P-Faktor). Die RUSLE-Faktoren wurden an die besonderen Umweltbedingungen des Schweizer Dauergrünlands angepasst. Der P-Faktor ist als Konstante mit dem Wert 1 in die Berechnung eingeflossen, da räumliche Daten zum Weidemanagement und dessen Einfluss auf die Bodenerosion fehlen. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU',
#     'inspireAbstract': 'Boden',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Boden',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,inspire,service-wms',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.tandfonline.com/doi/full/10.1080/17445647.2019.1585980',
#     'scaleLimit': '',
#     'dataStatus': '20190401',
#     'inspireUpperAbstract': 'Umwelt, Biologie und Geologie',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.erosion-gruenland_bodenabtrag/items/erosion-gruenland_bodenabtrag_apr',
#     'inspireUpperName': 'Umwelt, Biologie und Geologie',
#     'abstract': 'Monatliche Erosionsrisikokarten für das Schweizer Dauergrünland mit einer räumlichen Auflösung von 100 m. Die Karten zeigen den mittleren Bodenabtrag in Tonnen pro Hektare und Monat. Grüne Farbtöne bedeuten ein geringes, gelbe ein mittleres und rote ein hohes Erosionsrisiko.Die monatlichen Erosionsrisikokarten wurden mit der Revised Universal Soil Loss Equation (RUSLE) gerechnet. Für diese RUSLE-Anwendung wurde die monatliche Dynamik der Faktoren Niederschlagserosivität (R-Faktor) und Bodenbedeckung (C-Faktor) wie folgt berücksichtigt: A(Monat)=R(Monat)*K*C(Monat)*L*S*P wobei A(Monat) der Bodenabtrag in Tonnen pro Hektare und Monat und R(Monat) und C(Monat) der monatliche R-Faktor (MJ mm ha⁻¹ h⁻¹ Monat⁻¹) und C-Faktor (dimensionslos) sind. Die weiteren Erosionsfaktoren sind die Bodenerodierbarkeit (K-Faktor), die Hanglänge (L-Faktor) und die Hangneigung (S-Faktor) sowie Schutzmassnahmen (P-Faktor). Die RUSLE-Faktoren wurden an die besonderen Umweltbedingungen des Schweizer Dauergrünlands angepasst. Der P-Faktor ist als Konstante mit dem Wert 1 in die Berechnung eingeflossen, da räumliche Daten zum Weidemanagement und dessen Einfluss auf die Bodenerosion fehlen.',
#     'urlApplication': 'http://map.bafu.admin.ch'},
#    'idGeoCat': '6007a86c-7e1d-4f3c-a7d9-4eae01cac9c0',
#    'name': 'Erosionsrisiko Dauergrünland April',
#    'fullName': 'Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), April',
#    'layerBodId': 'ch.bafu.erosion-gruenland_bodenabtrag_apr'},
#   {'attributes': {'fullTextSearch': 'Badegewässerqualität | Die Beurteilung der Badegewässerqualität erfolgt anhand der Daten des kantonalen Gewässermonitorings zu den hygienischen Parametern E. coli und intestinale Enterokokken (Fäkalbakterien). Für die Beurteilung der Qualität gilt die EUA-Einstufung gemäss Anhang I der EU-Badegewässerrichtlinie 2006. Die EUA-Einstufung kann nur berechnet werden, wenn mindestens 4 Proben pro Badesaison und Messresultate für mindestens 4 Jahre vorliegen. | swisstopo | Bundesamt für Landestopografie swisstopo | Bundesamt für Umwelt BAFU',
#     'inspireAbstract': 'Gewässernetz',
#     'wmsContactAbbreviation': 'swisstopo',
#     'inspireName': 'Gewässernetz',
#     'wmsContactName': 'Bundesamt für Landestopografie swisstopo',
#     'maps': 'api,bafu,ech,gewiss,inspire,schule,service-wms,swissmaponline',
#     'wmsUrlResource': 'https://wms.geo.admin.ch/?REQUEST=GetCapabilities&SERVICE=WMS&VERSION=1.3.0',
#     'dataOwner': 'Bundesamt für Umwelt BAFU',
#     'urlDetails': 'https://www.bafu.admin.ch/bafu/de/home/themen/wasser/seen/wasserqualitaet-der-seen/badegewaesserqualitaet.html',
#     'scaleLimit': '-',
#     'dataStatus': '20241231',
#     'inspireUpperAbstract': 'Oberflächendarstellung',
#     'downloadUrl': 'https://data.geo.admin.ch/browser/index.html#/collections/ch.bafu.gewaesserschutz-badewasserqualitaet?.language=en',
#     'inspireUpperName': 'Oberflächendarstellung',
#     'abstract': 'Die Beurteilung der Badegewässerqualität erfolgt anhand der Daten des kantonalen Gewässermonitorings zu den hygienischen Parametern E. coli und intestinale Enterokokken (Fäkalbakterien). Für die Beurteilung der Qualität gilt die EUA-Einstufung gemäss Anhang I der EU-Badegewässerrichtlinie 2006. Die EUA-Einstufung kann nur berechnet werden, wenn mindestens 4 Proben pro Badesaison und Messresultate für mindestens 4 Jahre vorliegen.',
#     'urlApplication': 'http://map.bafu.admin.ch'},
#    'idGeoCat': '5601eb96-45cb-40a4-a595-2ec0ebda8e8c',
#    'name': 'Badegewässerqualität',
#    'fullName': 'Badegewässerqualität',
#    'layerBodId': 'ch.bafu.gewaesserschutz-badewasserqualitaet'}],
#  'spatialReference': {'wkid': 21781},
#  'tileInfo': {'rows': 256,
#   'cols': 256,
#   'dpi': 90.7,
#   'format': 'PNG,JPEG',
#   'compressionQuality': None,
#   'origin': {'x': 420000.0, 'y': 350000.0},
#   'spatialReference': {'wkid': 21781},
#   'lods': [{'level': 0,
#     'resolution': 4000.0,
#     'scale': 14285714.285714287,
#     'width': 1,
#     'height': 1},
#    {'level': 1,
#     'resolution': 3750.0,
#     'scale': 13392857.142857144,
#     'width': 1,
#     'height': 1},
#    {'level': 2,
#     'resolution': 3500.0,
#     'scale': 12500000.000000002,
#     'width': 1,
#     'height': 1},
#    {'level': 3,
#     'resolution': 3250.0,
#     'scale': 11607142.857142858,
#     'width': 1,
#     'height': 1},
#    {'level': 4,
#     'resolution': 3000.0,
#     'scale': 10714285.714285715,
#     'width': 1,
#     'height': 1},
#    {'level': 5,
#     'resolution': 2750.0,
#     'scale': 9821428.571428573,
#     'width': 1,
#     'height': 1},
#    {'level': 6,
#     'resolution': 2500.0,
#     'scale': 8928571.42857143,
#     'width': 1,
#     'height': 1},
#    {'level': 7,
#     'resolution': 2250.0,
#     'scale': 8035714.285714286,
#     'width': 1,
#     'height': 1},
#    {'level': 8,
#     'resolution': 2000.0,
#     'scale': 7142857.142857144,
#     'width': 1,
#     'height': 1},
#    {'level': 9,
#     'resolution': 1750.0,
#     'scale': 6250000.000000001,
#     'width': 2,
#     'height': 1},
#    {'level': 10,
#     'resolution': 1500.0,
#     'scale': 5357142.857142857,
#     'width': 2,
#     'height': 1},
#    {'level': 11,
#     'resolution': 1250.0,
#     'scale': 4464285.714285715,
#     'width': 2,
#     'height': 1},
#    {'level': 12,
#     'resolution': 1000.0,
#     'scale': 3571428.571428572,
#     'width': 2,
#     'height': 2},
#    {'level': 13,
#     'resolution': 750.0,
#     'scale': 2678571.4285714286,
#     'width': 3,
#     'height': 2},
#    {'level': 14,
#     'resolution': 650.0,
#     'scale': 2321428.571428572,
#     'width': 3,
#     'height': 2},
#    {'level': 15,
#     'resolution': 500.0,
#     'scale': 1785714.285714286,
#     'width': 4,
#     'height': 3},
#    {'level': 16,
#     'resolution': 250.0,
#     'scale': 892857.142857143,
#     'width': 8,
#     'height': 5},
#    {'level': 17,
#     'resolution': 100.0,
#     'scale': 357142.85714285716,
#     'width': 19,
#     'height': 13},
#    {'level': 18,
#     'resolution': 50.0,
#     'scale': 178571.42857142858,
#     'width': 38,
#     'height': 25},
#    {'level': 19,
#     'resolution': 20.0,
#     'scale': 71428.57142857143,
#     'width': 94,
#     'height': 63},
#    {'level': 20,
#     'resolution': 10.0,
#     'scale': 35714.28571428572,
#     'width': 188,
#     'height': 125},
#    {'level': 21,
#     'resolution': 5.0,
#     'scale': 17857.14285714286,
#     'width': 375,
#     'height': 250},
#    {'level': 22,
#     'resolution': 2.5,
#     'scale': 8928.57142857143,
#     'width': 750,
#     'height': 500},
#    {'level': 23,
#     'resolution': 2.0,
#     'scale': 7142.857142857143,
#     'width': 938,
#     'height': 625},
#    {'level': 24,
#     'resolution': 1.5,
#     'scale': 5357.142857142858,
#     'width': 1250,
#     'height': 834},
#    {'level': 25,
#     'resolution': 1.0,
#     'scale': 3571.4285714285716,
#     'width': 1875,
#     'height': 1250},
#    {'level': 26,
#     'resolution': 0.5,
#     'scale': 1785.7142857142858,
#     'width': 3750,
#     'height': 2500},
#    {'level': 27,
#     'resolution': 0.25,
#     'scale': 892.8571428571429,
#     'width': 7500,
#     'height': 5000},
#    {'level': 28,
#     'resolution': 0.1,
#     'scale': 357.14285714285717,
#     'width': 18750,
#     'height': 12500}]},
#  'initialExtent': {'xmin': 458000.0,
#   'ymin': 76375.0,
#   'xmax': 839125.0,
#   'ymax': 312500.0,
#   'spatialReference': {'wkid': 21781}},
#  'fullExtent': {'xmin': 420000.0,
#   'ymin': 30000.0,
#   'xmax': 900000.0,
#   'ymax': 350000.0,
#   'spatialReference': {'wkid': 21781}},
#  'units': 'esriMeters',
#  'capabilities': 'Map'}

# %%
# Puisque l'on a du json, on peut le traiter comme un dictionnaire ou une liste
# Une rapide ouverture de la page m'informe que le nom du journal est disponible à la clé ""

for resultat in req.json()["layers"]:
    print(resultat["name"], resultat["fullName"])
# Out:
# Energiestädte Energiestädte
# CadastralWebMap CadastralWebMap
# KbS Militär Kataster der belasteten Standorte im Bereich des Militärs (KbS VBS)
# Luftfahrthindernisse Luftfahrthindernisdaten Schweiz
# Feuchtflächenpotential Agrarland Feuchtflächenpotential der offenen Kulturlandschaft, Vektor
# Äschen: Larvenhabitate Äschenpopulationen von nationaler Bedeutung: Larvenhabitate
# Alpenkonvention Alpenkonvention
# Bauzonen Schweiz (harmonisiert) Bauzonen Schweiz (harmonisiert)
# swissEO VHI Wald swissEO VHI: Gesundheitszustand des Waldes
# Waldbrandpräventionsmassnahmen Waldbrandpräventionsmassnahmen der Kantone
# Personenverkehr Schiene 2050 Belastung (Personen) des schweizerischen Schienennetzes (Personenverkehr) 2050
# Äschen: Laichplätze Äschenpopulationen von nationaler Bedeutung: Laichplätze
# Personen-/Güterverkehr Strasse 2050 Belastung (Fahrzeuge) des schweizerischen Strassennetzes nach Fahrzeugkategorien (Personen- und Güterverkehr) 2050
# Erreichbarkeit auf der Strasse Erreichbarkeit auf der Strasse in Abhängigkeit von Reisezeit und Potenzial am Ziel
# Erreichbarkeit mit dem ÖV Erreichbarkeit mit dem öffentlichen Verkehr in Abhängigkeit von Reisezeit und Potenzial am Ziel
# öV-Haltestellen Haltestellen des öffentlichen Verkehrs
# Landwirtschaftliche Zonengrenzen Landwirtschaftliche Zonengrenzen der Schweiz
# Siedlung Siedlung
# Notfalltreffpunkte NTP Notfalltreffpunkte (NTP)
# Amtliches Gebäudeadressverzeichnis Amtliches Verzeichnis der Gebäudeadressen
# Auengebiete Bundesinventar der Auengebiete von nationaler Bedeutung
# Wind: Bundesinteressen Konzept Windenergie - Hinweiskarte auf Bundesinteressen für die Planung von Windenergieanlagen
# Wohnungsinventar Wohnungsinventar und Zweitwohnungsanteil
# NLA Naturwerte/ Lebensräume Natur Landschaft Armee (NLA), Naturwerte/ Lebensräume auf militärisch genutztem Gelände
# Hauptstrassennetz Hauptstrassennetz der Schweiz (MinVV)
# IVS Geländekarte Bundesinventar der historischen Verkehrswege der Schweiz, Geländekarte
# IVS National Bundesinventar der historischen Verkehrswege der Schweiz (IVS)
# IVS Abgrenzungen Bundesinventar der historischen Verkehrswege der Schweiz, Abgrenzungen
# IVS nationale Bed. hist. Verlauf Verlauf historischer Verkehrswege von nationaler Bedeutung ohne Substanz
# IVS Wegbegleiter Bundesinventar der historischen Verkehrswege der Schweiz, Wegbegleiter
# IVS Regional und Lokal Inventar der historischen Verkehrswege der Schweiz von regionaler und lokaler Bedeutung
# Konsultationsbereich Nationalstrassen Lage und angrenzende Bereiche gemäss Störfallverordnung im Bereich Nationalstrassen
# Mountainbikeland Schweiz Langsamverkehr - Mountainbikeland Schweiz
# Trockenheitswarnkarte Aktuelle Gefahrenstufe Trockenheit
# SP Infrastruktur Strasse Sachplan Verkehr - Teil Infrastruktur Strasse (SIN)
# Unfälle pro Einwohner - Alkohol Strassenverkehrsunfälle mit Schwerverunfallten und Hauptursache Alkohol pro 10'000 Einwohner nach Kanton
# Unfälle pro Einwohner - Geschwindig Strassenverkehrsunfälle mit Schwerverunfallten und Hauptursache Geschwindigkeit pro 10'000 Einwohner nach Kanton
# Unfälle im Jahresvergleich Strassenverkehrsunfälle mit Schwerverunfallten nach Kanton im Jahresvergleich
# Unfälle pro Einwohner Strassenverkehrsunfälle mit Schwerverunfallten pro 10'000 Einwohner nach Kanton
# Skatingland Schweiz Langsamverkehr - Skatingland Schweiz
# SWISSIMAGE Zeitreise SWISSIMAGE und Zeitreise - Luftbilder
# Verkehrszählung - übergeordnet Strassenverkehrszählung - übergeordnetes Netz
# Unfälle mit Personenschaden Strassenverkehrsunfälle mit Personenschaden
# Unfälle mit Fahrradbeteiligung Strassenverkehrsunfälle mit Personenschaden und Beteiligung mindestens eines Fahrrads (inkl. Fahrräder mit elektrischer Tretunterstützung)
# Unfälle mit Fussgängerbeteiligung Strassenverkehrsunfälle mit Personenschaden und Beteiligung mindestens eines Fussgängers
# Unfälle mit Getöteten Strassenverkehrsunfälle mit mindestens einer getöteten Person
# Unfälle mit Motorradbeteiligung Strassenverkehrsunfälle mit Personenschaden und Beteiligung mindestens eines Motorrads
# Veloland Schweiz Langsamverkehr - Veloland Schweiz
# Einteilung SWISSIMAGE 10 cm Raster Kachelung SWISSIMAGE 10 cm
# Wanderland Langsamverkehr - Wanderland Schweiz
# KGS Inventar Kulturgüterschutzinventar mit Objekten von nationaler Bedeutung
# Alpweiden mit Herdenschutzhunden Alpweiden geschützt durch Herdenschutzhunde
# Amphibienwanderungen mit Konflikten Amphibienwanderungen mit Verkehrskonflikten
# Alpine Auen ausserhalb Bundesinv. Alpine Auengebiete ausserhalb Bundesinventar
# Auen Vegetationskarten Kartierung der Auengebiete von nationaler Bedeutung
# Amphibien Ortsfeste Objekte Bundesinventar der Amphibienlaichgebiete von nationaler Bedeutung - Ortsfeste Objekte
# Amphibien Wanderobjekte Bundesinventar der Amphibienlaichgebiete von nationaler Bedeutung - Wanderobjekte
# Radioaktivität in der Atmosphäre Radioaktivität in der Atmosphäre
# Auengebiete - Anhang 2 Bundesinventar der Auengebiete von nationaler Bedeutung - Anhang 2
# Publizierte Schiessanzeigen und Gefahrenzonen Publizierte Schiessanzeigen und Gefahrenzonen
# BLN Bundesinventar der Landschaften und Naturdenkmäler (BLN)
# Flachmoore Bundesinventar der Flachmoore von nationaler Bedeutung
# Hochmoore Bundesinventar der Hoch- und Übergangsmoore von nationaler Bedeutung
# Jagdbanngebiete Bundesinventar der eidgenössischen Jagdbanngebiete (inkl. Routennetz) - Jagdbanngebiete
# Moorlandschaften Bundesinventar der Moorlandschaften von besonderer Schönheit und nationaler Bedeutung
# Trockenwiesen und -weiden (TWW) Bundesinventar der Trockenwiesen und -weiden von nationaler Bedeutung (TWW)
# Letzte Hindernisänderungen Luftfahrthindernisdaten Schweiz - Änderungen letzte 56 Tage
# Wasser- und Zugvogelreservate Bundesinventar der Wasser- und Zugvogelreservate von internationaler und nationaler Bedeutung
# Flugplatzhindernisse < 25 / 60 m Luftfahrthindernisdaten Schweiz - Flugplatzhindernisse < 25 / 60 m
# Steinbockkolonien Verbreitung der Steinbockkolonien
# Wildtierpassagen Wildtierpassagen
# Basiskarte GIN Basiskarte der Gemeinsamen Informationsplattform Naturgefahren
# Antimon-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Antimon
# Arsen-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Arsen
# Blei-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Blei
# Cadmium-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Cadmium
# Calcium - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Calcium
# Chrom-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Chrom
# Cobalt - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Cobalt
# Eisen - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Eisen
# Kupfer-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Kupfer
# Magnesium - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Magnesium
# Mangan - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Mangan
# Molybdän - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Molybdän
# Natrium - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Natrium
# Quecksilber-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Quecksilber
# Schwefel - Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Schwefel
# Thallium - Konzentration im Boden Geochemischer Bodenatlas der Schweiz: Thallium
# Uran-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Uran
# Vanadium-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Vanadium
# Konditoreiware Register Ursprungsbezeichnungen (GUB) und geografische Angaben (GGA) Konditoreiware
# Diffuse Gesamt-Phosphoreinträge Diffuse Gesamt-Phosphoreinträge in die Gewässer
# Diffuse gelöste Phosphoreinträge Diffuse gelöste Phosphoreinträge in die Gewässer, modellierte Werte
# Diffuse Gesamt-Stickstoffeinträge Diffuse Gesamt-Stickstoffeinträge in die Gewässer
# Uferbestockung der Flüsse Anteil der Bestockung entlang der Flüsse
# Bestockungskarte Bestockungskarte entlang Fliessgewässer und Seeufer
# Elektrische Anlagen Elektrische Anlagen mit einer Nennspannung von über 36 kV
# Hydrogeologische Karte 100 Hydrogeologische Karte der Schweiz 1:100000
# Messstandorte Gewässerzustand Bund Nationale Daueruntersuchung der schweizerischen Fliessgewässer (NADUF) - Standorte der Messstationen
# Minergie Minergie
# Hochwasserstatistik HQStat Hochwasserstatistik
# Niedrigwasserstatistik Niedrigwasserstatistik NQStat
# Grundlagen zur Bestimmung Q347 Grundlagen zur Bestimmung der Abflussmenge Q347
# GWR: Energie-/Wärmequelle Heizung Eidg. Gebäude- und Wohnungsregister: Energie-/Wärmequelle Heizung
# Messstationen Wassertemperatur Messstationen Wassertemperatur
# Einschränkungen für Drohnen Geografische UAS-Gebiete der Schweiz
# Bilanzgebiet Bilanzgebiete (Einzugsgebiete) HADES
# Flussgebiet Flussgebiete (Einzugsgebiete)
# Kantonale und private Messstationen Kantonale und private Messstationen (HADES 5.1.2)
# Elektrizitätsproduktionsanlagen Elektrizitätsproduktionsanlagen
# NAQUA-QUANT Messstellen NAQUA-QUANT Messstellen (Nationale Grundwasserbeobachtung NAQUA)
# Äschen: Verbreitungsgebiet Äschenpopulationen von nationaler Bedeutung: Verbreitungsgebiet
# Meldungen zu Karten und Geodaten Meldungen zu Karten und Geodaten
# Übersichtskarte Hydrogeologie Hydrogeologische Übersichtskarte der Schweiz
# Markierversuche Markierversuche im Grundwasser
# Zink-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Zink
# Karstwasservorkommen Ausdehnung der Grundwasservorkommen in Karstgebieten
# Karst-Einzugsgebiete Einzugsgebiete in Karstgebieten
# Karst-Einzugsgebietseinheiten Einzugsgebietseinheiten in Karstgebieten
# Karstquellen und Schwinden Quellen und Schwinden in Karstgebieten
# Unterirdische Fliesswege Unterirdische Fliesswege in Karstgebieten
# Baulinien Nationalstrassen Baulinien Nationalstrassen
# Nickel-Konzentrationen im Boden Geochemischer Bodenatlas der Schweiz: Nickel
# Lagefixpunkte LFP1 Lagefixpunkte LFP1 (Landesvermessung)
# Mobilfunkanlagen Mobilfunkanlagen
# swissEO VHI Vegetation swissEO VHI: Gesundheitszustand der Vegetation
# Vegetationshöhe LFI Vegetationshöhenmodell LFI
# Vegetationshöhe Lidar LFI Vegetationshöhenmodell Lidar LFI
# Oberflächenmodell LFI Reliefschattierung zum Vegetationshöhenmodell LFI
# Reliefschattierung Sentinel LFI Reliefschattierung zum Vegetationshöhenmodell Sentinel LFI
# Vegetationshöhe Sentinel LFI Vegetationshöhenmodell Sentinel LFI
# Waldmischungsgrad LFI Waldmischungsgrad LFI
# Wasserpflanzen (Makrophyten) Beurteilung des biologischen Gewässerzustandes: Wasserpflanzen (Makrophyten)
# Lebensraumkarte Lebensraumkarte der Schweiz
# Ammoniakkonzentration Ammoniakkonzentration
# Feinstaub PM10 Luftbelastung durch Feinstaub PM10
# Feinstaub PM2.5 Luftbelastung durch Feinstaub PM2.5
# Ozon mp98 Oᴣ Luftbelastung durch Ozon
# Schwefeldioxid SO₂ Luftbelastung durch Schwefeldioxid
# Stickstoffdeposition Stickstoffdeposition
# Stickstoffdioxid NO₂ Luftbelastung durch Stickstoffdioxid
# CLN Überschreitung Überschreitung der kritischen Eintragsgrenzen (Critical Loads) für Stickstoff
# Mittlere Abflüsse (m³/s) und Regime Mittlere Abflüsse (m³/s) und Abflussregimetyp für das Gewässernetz der Schweiz
# Mittlere Abflüsse in der Zukunft Mittlere Abflüsse in der Zukunft – Resultate aus dem Projekt Hydro-CH2018
# Rote Liste Moose  Rote Liste Moose (Gefährdung der Moose in der Schweiz)
# Höhenfixpunkte HFP1 Höhenfixpunkte HFP1 (Landesvermessung)
# Amerikanische Kermesbeere Invasive gebietsfremde Pflanzen - Potentialkarte Amerikanische Kermesbeere
# Amerikanischer Stinktierkohl Invasive gebietsfremde Pflanzen - Potentialkarte Amerikanischer Stinktierkohl
# Armenische Brombeere Invasive gebietsfremde Pflanzen - Potentialkarte Armenische Brombeere
# Aufrechtes Traubenkraut Invasive gebietsfremde Pflanzen - Potentialkarte Aufrechtes Traubenkraut
# Ausläuferbildendes Fettkraut Invasive gebietsfremde Pflanzen - Potentialkarte Ausläuferbildendes Fettkraut
# Balfours Springkraut Invasive gebietsfremde Pflanzen - Potentialkarte Balfours Springkraut
# Bastardindigo Invasive gebietsfremde Pflanzen - Potentialkarte Bastardindigo
# Bastard-Staudenknöterich Invasive gebietsfremde Pflanzen - Potentialkarte Bastard-Staudenknöterich
# Besen-Radmelde Invasive gebietsfremde Pflanzen - Potentialkarte Besen-Radmelde
# Blauglockenbaum Invasive gebietsfremde Pflanzen - Potentialkarte Blauglockenbaum
# Brasilianisches Tausendblatt Invasive gebietsfremde Pflanzen - Potentialkarte Brasilianisches Tausendblatt
# Carolina-Nachtschatten Invasive gebietsfremde Pflanzen - Potentialkarte Carolina-Nachtschatten
# Chinesische Samtpappel Invasive gebietsfremde Pflanzen - Potentialkarte Chinesische Samtpappel
# Drüsiges Springkraut Invasive gebietsfremde Pflanzen - Potentialkarte Drüsiges Springkraut
# Einjähriges Berufkraut Invasive gebietsfremde Pflanzen - Potentialkarte Einjähriges Berufkraut
# Essbare Kermesbeere Invasive gebietsfremde Pflanzen - Potentialkarte Essbare Kermesbeere
# Essbares Zypergras Invasive gebietsfremde Pflanzen - Potentialkarte Essbares Zypergras
# Essigbaum Invasive gebietsfremde Pflanzen - Potentialkarte Essigbaum
# Felsen-Greiskraut Invasive gebietsfremde Pflanzen - Potentialkarte Felsen-Greiskraut
# Fortunes Hanfpalme Invasive gebietsfremde Pflanzen - Potentialkarte Fortunes Hanfpalme
# Gestreiftes Süssgras Invasive gebietsfremde Pflanzen - Potentialkarte Gestreiftes Süssgras
# Gewöhnliche Jungfernrebe Invasive gebietsfremde Pflanzen - Potentialkarte Gewöhnliche Jungfernrebe
# Glattes Zackenschötchen Invasive gebietsfremde Pflanzen - Potentialkarte Glattes Zackenschötchen
# Götterbaum Invasive gebietsfremde Pflanzen - Potentialkarte Götterbaum
# Grossblütiges Heusenkraut Invasive gebietsfremde Pflanzen - Potentialkarte Grossblütiges Heusenkraut
# Grosser Wassernabel Invasive gebietsfremde Pflanzen - Potentialkarte Grosser Wassernabel
# Haargurke Invasive gebietsfremde Pflanzen - Potentialkarte Haargurke
# Henrys Geissblatt Invasive gebietsfremde Pflanzen - Potentialkarte Henrys Geissblatt
# Herbst-Traubenkirsche Invasive gebietsfremde Pflanzen - Potentialkarte Herbst-Traubenkirsche
# Igelgurke Invasive gebietsfremde Pflanzen - Potentialkarte Igelgurke
# Japanischer Staudenknöterich Invasive gebietsfremde Pflanzen - Potentialkarte Japanischer Staudenknöterich
# Japanisches Geissblatt Invasive gebietsfremde Pflanzen - Potentialkarte Japanisches Geissblatt
# Kanadische Goldrute Invasive gebietsfremde Pflanzen - Potentialkarte Kanadische Goldrute
# Kanadische Wasserpest Invasive gebietsfremde Pflanzen - Potentialkarte Kanadische Wasserpest
# Karolina-Haarnixe Invasive gebietsfremde Pflanzen - Potentialkarte Karolina-Haarnixe
# Kaukasus-Fettkraut Invasive gebietsfremde Pflanzen - Potentialkarte Kaukasus-Fettkraut
# Kirschlorbeer Invasive gebietsfremde Pflanzen - Potentialkarte Kirschlorbeer
# Kletternder Giftsumach Invasive gebietsfremde Pflanzen - Potentialkarte Kletternder Giftsumach
# Kopoubohne Invasive gebietsfremde Pflanzen - Potentialkarte Kopoubohne
# Mahonie Invasive gebietsfremde Pflanzen - Potentialkarte Mahonie
# Nadelkraut Invasive gebietsfremde Pflanzen - Potentialkarte Nadelkraut
# Nuttalls Wasserpest Invasive gebietsfremde Pflanzen - Potentialkarte Nuttalls Wasserpest
# Portulak-Heusenkraut Invasive gebietsfremde Pflanzen - Potentialkarte Portulak-Heusenkraut
# Riesenbärenklau Invasive gebietsfremde Pflanzen - Potentialkarte Riesenbärenklau
# Robinie Invasive gebietsfremde Pflanzen - Potentialkarte Robinie
# Runzelblättriger Schneeball Invasive gebietsfremde Pflanzen - Potentialkarte Runzelblättriger Schneeball
# Sachalin-Staudenknöterich Invasive gebietsfremde Pflanzen - Potentialkarte Sachalin-Staudenknöterich
# Schmetterlingsstrauch Invasive gebietsfremde Pflanzen - Potentialkarte Schmetterlingsstrauch
# Seidiger Hornstrauch Invasive gebietsfremde Pflanzen - Potentialkarte Seidiger Hornstrauch
# Spätblühende Goldrute Invasive gebietsfremde Pflanzen - Potentialkarte Spätblühende Goldrute
# Südafrikanisches Greiskraut Invasive gebietsfremde Pflanzen - Potentialkarte Südafrikanisches Greiskraut
# Syrische Seidenpflanze Invasive gebietsfremde Pflanzen - Potentialkarte Syrische Seidenpflanze
# Topinambur Invasive gebietsfremde Pflanzen - Potentialkarte Topinambur
# Verlotscher Beifuss Invasive gebietsfremde Pflanzen - Potentialkarte Verlotscher Beifuss
# Vielähriger Knöterich Invasive gebietsfremde Pflanzen - Potentialkarte Vielähriger Knöterich
# Vielblättrige Lupine Invasive gebietsfremde Pflanzen - Potentialkarte Vielblättrige Lupine
# Phosphat Beurteilung des chemischen Gewässerzustandes: Phosphat
# Waldbrandgefahr Waldbrandgefahrenwarnung
# GWR: Gebäudestatus Eidg. Gebäude- und Wohnungsregister: Gebäudestatus
# Sperrungen Wanderwege Sperrungen / Umleitungen Wanderwege und Wanderland
# Äschen: Kernzonen Äschenpopulationen von nationaler Bedeutung: Kernzonen
# Nitrit Beurteilung des chemischen Gewässerzustandes: Nitrit
# Photovoltaik-Grossanlagen Photovoltaik Grossanlagen in der Schweiz
# Luftbilder swisstopo farbig Luftbilder swisstopo farbig
# Luftbilder swisstopo s/w Luftbilder swisstopo schwarzweiss
# Nitrat Beurteilung des chemischen Gewässerzustandes: Nitrat
# Impulsberatung EFH und kleine MFH Impulsberatung erneuerbar heizen: EFH und MFH bis 6 Wohneinheiten
# swissBATHY3D Reliefschattierung swissBATHY3D Reliefschattierung : Bathymetrische Daten
# Sperrungen Velo Sperrungen / Umleitungen Veloland
# Ökomorphologie F - Abschnitte Ökomorphologie Stufe F - Abschnitte
# Impulsberatung grosse MFH Impulsberatung erneuerbar heizen: MFH mit mehr als 6 Wohneinheiten
# Ökomorphologie F - Abstürze Ökomorphologie Stufe F - Abstürze
# Ökomorphologie F - Bauwerke Ökomorphologie Stufe F - Bauwerke
# Permafrosthinweiskarte Hinweiskarte der potenziellen Permafrostverbreitung
# REN  Extensives Landwirtschaftsgebiet Nationales ökologisches Netzwerk REN, Lebensraum Extensives Landwirtschaftsgebiet
# REN  Feuchtgebiet Nationales ökologisches Netzwerk REN, Lebensraum Feuchtgebiet
# REN  Fliessgewässer / Seen Nationales ökologisches Netzwerk REN, Lebensraum Fliessgewässer / Seen
# REN  Trockenstandort Nationales ökologisches Netzwerk REN, Lebensraum Trockenstandort
# REN  Wald Nationales ökologisches Netzwerk REN, Lebensraum Wald
# swissEO S2-SR swissEO S2-SR: Optische Satellitendaten (Sentinel-2)
# Auengebiete AuLaV Schutzgebiete der zivilen Luftfahrthindernispublikation - Auengebiete
# Jagdbanngebiete AuLaV Schutzgebiete der zivilen Luftfahrthindernispublikation - Jagdbanngebiete
# Moorlandschaften AuLaV Schutzgebiete der zivilen Luftfahrthindernispublikation - Moorlandschaften
# Übrige Schutzgebiete AuLaV Schutzgebiete der zivilen Luftfahrthindernispublikation - Übrige Schutzgebiete
# Schweizer Pärke (Zonierung) Schweizerischer Nationalpark und Pärke von nationaler Bedeutung (Zonierung)
# Schweizer Pärke (Perimeter) Schweizerischer Nationalpark und Pärke von nationaler Bedeutung (Perimeter)
# Ramsar Übereinkommen über Feuchtgebiete, insbesondere als Lebensraum für Wasser- und Watvögel, von internationaler Bedeutung (Ramsar-Konvention)
# Strukturgüte Linkes Ufer Strukturgüte Hochrhein (2020)
# Strukturgüte Linkes Umfeld Strukturgüte Hochrhein (2020)
# Strukturgüte Rechtes Ufer Strukturgüte Hochrhein (2020)
# Strukturgüte Rechtes Umfeld Strukturgüte Hochrhein (2020)
# Strukturgüte Sohle Strukturgüte Hochrhein (2020)
# Sturmgefährdung Böenspitzen 100 Sturmgefährdung: Böenspitzen mit Wiederkehrperiode 100 Jahre
# Sturmgefährdung Böenspitzen 30 Sturmgefährdung: Böenspitzen mit Wiederkehrperiode 30 Jahre
# Sturmgefährdung Böenspitzen 300 Sturmgefährdung: Böenspitzen mit Wiederkehrperiode 300 Jahre
# Sturmgefährdung Böenspitzen 50 Sturmgefährdung: Böenspitzen mit Wiederkehrperiode 50 Jahre
# Sturmgefährdung Staudruck 100 Sturmgefährdung: Staudruck mit Wiederkehrperiode 100 Jahre
# Sturmgefährdung Staudruck 30 Sturmgefährdung: Staudruck mit Wiederkehrperiode 30 Jahre
# Sturmgefährdung Staudruck 300 Sturmgefährdung: Staudruck mit Wiederkehrperiode 300 Jahre
# Sturmgefährdung Staudruck 50 Sturmgefährdung: Staudruck mit Wiederkehrperiode 50 Jahre
# Schadstoff-Freisetzungen (SwissPRTR) Schadstofffreisetzungs- und -transferregister der Schweiz (SwissPRTR)
# Tranquillity Gebiete Tranquillity Gebiete
# Tranquillity Map Tranquillity Map
# Fleischware Register Ursprungsbezeichnungen (GUB) und geografische Angaben (GGA) Fleischware
# Sperrungen Skating Sperrungen / Umleitungen Skatingland
# Typisierung Fliessgewässer Typisierung der Schweizer Fliessgewässer
# UNESCO-Welterbe Naturstätten UNESCO-Welterbe Naturstätten
# Gewässernetz 1:2 Mio. Gewässer der Übersichtskarte 1:2 Mio
# Seen Seen
# Föhnhäufigkeit Föhnhäufigkeit im Jahr, Periode variabel (maximal 1969-2013)
# Kontinentalität 1000 m 1995 Thermische Kontinentalität auf 1000 m ü. M. im Jahr, Periode 1981-2010
# Kontinentalität 1000 m Juli 1995 Thermische Kontinentalität auf 1000 m ü. M. im Juli, Periode 1981-2010
# Lufttemperatur Juli 1961-1990 Mittlere Höchstwerte des Tagesganges der Lufttemperatur im Juli, Periode 1961-1990
# Lufttemperatur Juli 1981-2010 Mittlere Höchstwerte des Tagesganges der Lufttemperatur im Juli, Periode 1981-2010
# Lufttemperatur Juli 2085, RCP 2.6 Mittlere Höchstwerte des Tagesganges der Lufttemperatur im Juli, Periode 2070-2099, Szenario RCP 2.6
# Lufttemperatur Juli 2085, RCP 4.5 Mittlere Höchstwerte des Tagesganges der Lufttemperatur im Juli, Periode 2070-2099, Szenario RCP 4.5
# Lufttemperatur Juli 2085, RCP 8.5 Mittlere Höchstwerte des Tagesganges der Lufttemperatur im Juli, Periode 2070-2099, Szenario RCP 8.5
# Niederschlag April-August 2085, RCP 2.6 Niederschlagssumme April-August, Periode 2070-2099, Szenario RCP 2.6
# Niederschlag April-August 2085, RCP 4.5 Niederschlagssumme April-August, Periode 2070-2099, Szenario RCP 4.5
# Niederschlag April-August 2085, RCP 8.5 Niederschlagssumme April-August, Periode 2070-2099, Szenario RCP 8.5
# Niederschlag Sommer 2085, RCP 2.6 Niederschlagssumme Juni-August, Periode 2070-2099, Szenario RCP 2.6
# Niederschlag Sommer 2085, RCP 4.5 Niederschlagssumme Juni-August, Periode 2070-2099, Szenario RCP 4.5
# Niederschlag Sommer 2085, RCP 8.5 Niederschlagssumme Juni-August, Periode 2070-2099, Szenario RCP 8.5
# Obere Waldgrenze Ermittlung und Modellierung der oberen Waldgrenze für die Normperioden 1961-1990, 1981-2010 und die Zukunftsperiode 2070-2099
# Rel. Luftfeuchte Jahr, 1981-2010 Relative Luftfeuchtigkeit im Jahr, Periode 1981-2010
# Rel. Luftfeuchte Juli, 1981-2010 Relative Luftfeuchtigkeit im Juli, Periode 1981-2010
# Waldreservate Waldreservate
# Waldstandortsregionen Waldstandortsregionen
# Tannenareale Tannenareale
# Höhenstufen 1975 Vegetationshöhenstufen modelliert für 1975
# Höhenstufen 2085 trocken Vegetationshöhenstufen modelliert für 2085 mit trockener Klimazukunft
# Höhenstufen 2085 mässig trocken Vegetationshöhenstufen modelliert für 2085 mit weniger trockener Klimazukunft
# Wasserverfügbarkeit im Boden Wasserverfügbarkeit im Boden (Standortwasserbilanz)
# Wasserverfügbarkeit für Pflanzen Wasserverfügbarkeit für Pflanzen (Transpirationsverhältnis)
# Querprofilachse Datenbank Querprofile (QP) - Querprofilachse
# Vermessungsabschnitt Datenbank Querprofile (QP) - Vermessungsabschnitt
# Wasserentnahme Restwasserkarte Schweiz: Wasserentnahme
# Gebietsauslässe Topographische Einzugsgebiete Schweizer Gewässer: Gebietsauslässe
# Zuleitung Restwasserkarte Schweiz: Zuleitung
# Wasserrückgabe Restwasserkarte Schweiz: Wasserrückgabe
# Teileinzugsgebiete 2 km² Topographische Einzugsgebiete Schweizer Gewässer: Teileinzugsgebiete 2 km²
# Teileinzugsgebiete 40 km² Topographische Einzugsgebiete der Schweizer Gewässer: Teileinzugsgebiete 40 km²
# Vorfluterabschnitte Topographische Einzugsgebiete Schweizer Gewässer: Vorfluterabschnitte
# Wildtierschutzgebiete Wildtierschutzgebiete
# Wildruhezonen Wildruhezonen
# Makrozoobenthos Beurteilung des biologischen Gewässerzustandes: Makrozoobenthos
# Radonkarte Radonkarte
# FSME - Gemeldete Stichorte Gemeldete Stichorte der Frühsommer-Meningoenzephalitis (FSME), Schweiz, 2012-2024
# FSME - Impfempfehlung Zeckenenzephalitis / Frühsommer-Meningoenzephalitis (FSME) - Impfempfehlung
# Zeckenmodell Zeckenmodell
# ISOS - Ortsbildaufnahmen ISOS - Bundesinventar der schützenswerten Ortsbilder der Schweiz von nationaler Bedeutung ab 2021 - Ortsbildaufnahmen
# ISOS - Bilder ISOS - Bundesinventar der schützenswerten Ortsbilder der Schweiz von nationaler Bedeutung ab 2021 - Bilder
# Plätze für Jenische, Sinti und Roma Standplätze, Durchgangs und Transitplätze für Jenische, Sinti und Roma
# Anzahl Dienstanbieter Anzahl Festnetz-Dienstanbieter
# Glasfaser FTTB/FTTH Verfügbare Anschlussarten Glasfaser FTTB/FTTH
# Koaxial-Kabel Verfügbare Anschlussarten Koaxial-Kabel
# Kupfer-Draht Verfügbare Anschlussarten Kupfer-Draht
# Download ≥ 10 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 10 Mbit/s
# Download ≥ 100 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 100 Mbit/s
# Download ≥ 1000 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 1000 Mbit/s
# Download ≥ 30 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 30 Mbit/s
# Download ≥ 300 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 300 Mbit/s
# Download ≥ 500 Mbit/s Internet-Verfügbarkeit via Festnetz: Download Geschwindigkeit ≥ 500 Mbit/s
# 2G - GSM / EDGE 2G - GSM / EDGE Verfügbarkeit
# 3G - UMTS / HSPA 3G - UMTS / HSPA Verfügbarkeit
# 4G - LTE / LTE-A 4G - LTE / LTE-A Verfügbarkeit
# 5G - NR 5G - NR Verfügbarkeit
# Notrufe per Gemeinde Notrufe per Gemeinde
# 112 Festnetz Einzugsgebiete für die Notrufnummer 112 im Festnetz
# 112 Mobilnetz Einzugsgebiete für die Notrufnummer 112 im Mobilnetz
# 112 Alarmzentralen Einzugsgebiete von Alarmzentralen 112
# 117 Festnetz Einzugsgebiete für die Notrufnummer 117 im Festnetz
# 117 Mobilnetz Einzugsgebiete für die Notrufnummer 117 im Mobilnetz
# 117 Alarmzentralen Einzugsgebiete von Alarmzentralen 117
# 118 Festnetz Einzugsgebiete für die Notrufnummer 118 im Festnetz
# 118 Mobilnetz Einzugsgebiete für die Notrufnummer 118 im Mobilnetz
# 118 Alarmzentralen Einzugsgebiete von Alarmzentralen 118
# 142 Festnetz Einzugsgebiete für die Notrufnummer 142 im Festnetz
# 142 Mobilnetz Einzugsgebiete für die Notrufnummer 142 im Mobilfunknetz
# 142 Alarmzentralen Einzugsgebiete von Alarmzentralen 142
# 143 Festnetz Einzugsgebiete für die Notrufnummer 143 im Festnetz
# 143 Mobilnetz Einzugsgebiete für die Notrufnummer 143 im Mobilnetz
# 143 Alarmzentralen Einzugsgebiete von Alarmzentralen 143
# 144 Festnetz Einzugsgebiete für die Notrufnummer 144 im Festnetz
# 144 Mobilnetz Einzugsgebiete für die Notrufnummer 144 im Mobilnetz
# 144 Alarmzentralen Einzugsgebiete von Alarmzentralen 144
# 145 Festnetz Einzugsgebiete für die Notrufnummer 145 im Festnetz
# 145 Mobilnetz Einzugsgebiete für die Notrufnummer 145 im Mobilnetz
# 145 Alarmzentralen Einzugsgebiete von Alarmzentralen 145
# 147 Festnetz Einzugsgebiete für die Notrufnummer 147 im Festnetz
# 147 Mobilnetz Einzugsgebiete für die Notrufnummer 147 im Mobilnetz
# 147 Alarmzentralen Einzugsgebiete von Alarmzentralen 147
# Arbeitsmarktregionen und Arbeitsmarktgrossregionen Arbeitsmarktregionen und Arbeitsmarktgrossregionen
# Fische Beurteilung des biologischen Gewässerzustandes: Fische
# Upload ≥ 1 Mbit/s Internet-Verfügbarkeit via Festnetz: Upload Geschwindigkeit ≥ 1 Mbit/s
# Upload ≥ 10 Mbit/s Internet-Verfügbarkeit via Festnetz: Upload Geschwindigkeit ≥ 10 Mbit/s
# Upload ≥ 100 Mbit/s Internet-Verfügbarkeit via Festnetz: Upload Geschwindigkeit ≥ 100 Mbit/s
# Upload ≥ 1000 Mbit/s Internet-Verfügbarkeit via Festnetz: Upload Geschwindigkeit ≥ 1000 Mbit/s
# Versorgungsgebiete TV Lokale/regionale Versorgungsgebiete TV
# Versorgungsgebiete Radio Lokale/regionale Versorgungsgebiete Radio
# UNESCO-Welterbe Kulturstätten UNESCO-Welterbe Kulturstätten
# Sportanlagen NASAK Konzept der Sportanlagen von nationaler Bedeutung NASAK
# Anlagen Gütertransport Schiene Bestand der Anlagen für den Schienengüterverkehr gemäss Konzept für den Gütertransport auf der Schiene
# Eisenbahnbetriebe StFV Betriebe gemäss Störfallverordnung im Bereich Eisenbahnanlagen
# Kieselalgen (Diatomeen) Beurteilung des biologischen Gewässerzustandes: Kieselalgen (Diatomeen)
# Wirtschaftsregionen LFI Wirtschaftsregionen LFI
# Schutzwaldregionen LFI Schutzwaldregionen LFI
# Eisenbahnlärm, tats. Immission N Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, tatsächliche Immissionen Nacht
# Eisenbahnlärm, tats. Immission T Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, tatsächliche Immissionen Tag
# Eisenbahnlärm, festgel. Emission N Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, festgelegte Emissionen Nacht
# Produktionsregionen LFI Produktionsregionen LFI
# Eisenbahnlärm, festgel. Emission T Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, festgelegte Emissionen Tag
# Eisenbahnlärm, Lärmschutzwände Lärmbelastungskataster für Eisenbahnanlagen - Lärmschutzwände
# Eisenbahnlärm, tats. Emission N Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, tatsächliche Emissionen Nacht
# Eisenbahnlärm, tats. Emission T Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, tatsächliche Emissionen Tag
# Eisenbahnlärm, zuläss. Immission N Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, zulässige Immissionen Nacht
# Eisenbahnlärm, zuläss. Immission T Lärmbelastungskataster für Eisenbahnanlagen - Eisenbahnlärm, zulässige Immissionen Tag
# Eisenbahnstrecken StFV Lage und angrenzende Bereiche gemäss Störfallverordnung im Bereich Eisenbahnanlagen
# SP Infrastruktur Schiene Sachplan Verkehr, Teil Infrastruktur Schiene (SIS)
# SP Infrastruktur Schifffahrt Sachplan Verkehr, Teil Infrastruktur Schifffahrt (SIF)
# SUG Anhörung Sachplan Verkehr, Teil Unterirdischer Gütertransport (SUG): Anhörung
# Strassenverkehrslärm Tag Lärmbelastung durch Strassenverkehr (Lr_Tag)
# Schienennetz Schienennetz
# Strassenverkehrslärm Nacht Lärmbelastung durch Strassenverkehr (Lr_Nacht)
# Seilbahnen mit Bundeskonzession Seilbahnen mit Bundeskonzession
# Bebaute Gebiete VIL Bebaute Gebiete nach Schweizer Luftfahrtrecht
# Betriebe zivile Flugplätze - StFV Lage und angrenzende Bereiche von Betrieben gemäss Störfallverordnung im Bereich ziviler Flugplätze
# Eisenbahnlärm Tag Lärmbelastung durch Eisenbahnverkehr (Lr_Tag)
# Flugplätze + Heliports Zivile und militärische Flugplätze
# Gebirgslandeplätze Gebirgslandeplätze: speziell bezeichnete Landestellen über 1100 m über Meer
# SORA Bodenrisiko SORA-Karte für intrinsisches Bodenrisiko
# Eisenbahnlärm Nacht Lärmbelastung durch Eisenbahnverkehr (Lr_Nacht)
# Sperrungen Mountainbike Sperrungen / Umleitungen Mountainbikeland
# Lärmbelastung 1. Nachtstunde Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung 1. Nachtstunde Lrn (22-23 Uhr)
# Lärmbelastung Helikopter Lr Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung Helikopter Lr
# Lärmbelastung Helikopter Lmax Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung Helikopter Lmax
# Lärmbelast. Klein- / Grossflugzeuge Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung Kleinluftfahrzeuge und Grossflugzeuge Lrt (06-22 Uhr)
# Lärmbelastung Kleinluftfahrzeuge Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung Kleinluftfahrzeuge Lrk
# Lärmbelastung letzte Nachtstunde Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung letzte Nachtstunde Lrn (05-06 Uhr)
# Lärmbelast. Militärflugpl. (gesamt) Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung Militärflugplatz inkl. ziviler Flugverkehr Lr
# Lärmbelastung 2. Nachtstunde Lärmbelastungskataster für zivile Flugplätze - Lärmbelastung 2. Nachtstunde Lrn (23-24 Uhr)
# Landschaftsruhezonen Landschaftsruhezonen für die Luftfahrt
# Luftfahrtkarte ICAO Luftfahrtkarte ICAO Schweiz 1:500'000
# Lufträume - FIR Lufträume: Fluginformationsgebiet (FIR)
# Lufträume - FIZ Lufträume: Fluginformationszonen (FIZ)
# Lufträume - CTA Lufträume: Kontrollbezirke (CTA)
# Lufträume - CTR Lufträume: Kontrollzonen (CTR)
# Lufträume - TMA Lufträume: Nahkontrollbezirke (TMA)
# Projektierungszonen Flughäfen Projektierungszonen Flughafenanlagen
# SP Infrastruktur Luftfahrt Sachplan Verkehr, Teil Infrastruktur Luftfahrt (SIL)
# Segelflugkarte Segelflugkarte Schweiz 1:300'000
# Sicherheitszonenplan Sicherheitszonenplan
# Wohngebiete nach AuLaV Wohngebiete nach Aussenlandeverordnung (AuLaV)
# Verzicht Wasserkraftnutzung Abgeltung von Einbussen der Wasserkraftnutzung (VAEW)
# Biogasanlagen Biogasanlagen
# Nicht-verholzte Biomassen Nachhaltiges Potenzial der nicht-verholzten Biomassenressourcen für Bioenergie in der Schweiz auf Gemeindeebene
# Verholzte Biomassen Nachhaltiges Potenzial der verholzten Biomassenressourcen für Bioenergie in der Schweiz auf Gemeindeebene
# Reflexionsseismik 2D und 3D Reflexionsseismik in der Schweiz
# Energieberatungsstellen Öffentliche Energieberatungsstellen
# 2000-Watt-Areale 2000-Watt-Areale
# Pflanzliche Produkte Register Ursprungsbezeichnungen (GUB) und geografische Angaben (GGA) Pflanzliche Produkte
# Potenzial Wärmenutzung ARA Potenzial der Abwasserreinigungsanlagen für Wärmenutzung
# Wärme-/Kältenachfrage Industrie Thermische Netze: Nachfrage Industrie
# Wärme-/Kältenachfrage Wohnen und DL Thermische Netze: Nachfrage Wohn- und Dienstleistungsgebäude
# Grundwasserwärmenutzungspotenzial Grundwasserwärmenutzungspotenzial
# Kehrichtverbrennungsanlagen Kehrichtverbrennungsanlagen (KVA)
# Kernkraftwerke Kernkraftwerke
# Kleinwasserkraftpotentiale Kleinwasserkraftpotentiale der Schweizer Gewässer
# Mobilitätsprojekte Mobilitätsprojekte
# Ladebedarf: Steckerfahrzeuge Ladebedarf: Bestand an Steckerfahrzeugen für das Jahr 2035
# Ladebedarf: Heimladeverfügbarkeit - Bequem Ladebedarf: Heimladeverfügbarkeit in der Ladewelt "Bequem" für das Jahr 2035
# Ladebedarf: Heimladeverfügbarkeit - Flexibel Ladebedarf: Heimladeverfügbarkeit in der Ladewelt "Flexibel" für das Jahr 2035
# Ladebedarf: Heimladeverfügbarkeit - Geplant Ladebedarf: Heimladeverfügbarkeit in der Ladewelt "Geplant" für das Jahr 2035
# Ladebedarf: Ladepunkte - Bequem Ladebedarf: Anzahl allgemein zugängliche Ladepunkte in der Ladewelt «Bequem» für das Jahr 2035
# Ladebedarf: Ladepunkte - Flexibel Ladebedarf: Anzahl allgemein zugängliche Ladepunkte in der Ladewelt «Flexibel» für das Jahr 2035
# Ladebedarf: Ladepunkte - Geplant Ladebedarf: Anzahl allgemein zugängliche Ladepunkte in der Ladewelt «Geplant» für das Jahr 2035
# Ladebedarf: Strombedarf - Bequem Ladebedarf: Strombedarf in der Ladewelt "Bequem" für Steckerfahrzeuge für das Jahr 2035
# Nationalstrassenachsen Nationalstrassenachsen
# Vereisungshäufigkeit Windatlas Schweiz: Häufigkeit meteorologischer Vereisung in 100 m Höhe über Grund
# Ammonium Beurteilung des chemischen Gewässerzustandes: Ammonium
# Konsultationsbereiche Rohrleitungen Lage und angrenzende Bereiche gemäss Störfallverordnung im Bereich Rohrleitungsanlagen
# SP Geologische Tiefenlager Sachplan geologische Tiefenlager
# SÜL Anhörung Sachplan Übertragungsleitungen (SÜL) - Anhörungen
# SP Übertragungsleitungen Sachplan Übertragungsleitungen (SÜL)
# Solarenergie: Eignung Dächer Eignung von Hausdächern für die Nutzung von Sonnenenergie
# Solarenergie: Eignung Fassaden Eignung von Hausfassaden für die Nutzung von Sonnenenergie
# Solare Einstrahlung horizontal Solare Einstrahlung auf eine horizontale Fläche
# Solare Einstrahlung 30°Neigung Süd Solare Einstrahlung auf eine 30° nach Süden geneigte Fläche
# Solare Einstrahlung 75°Neigung Süd Solare Einstrahlung auf eine 75° nach Süden geneigte Fläche
# Solare Einstrahlung 90°Neigung Süd Solare Einstrahlung auf eine 90° nach Süden geneigte Fläche
# Stauanlagen Stauanlagen unter Bundesaufsicht
# Potenzial Wärmenutzung Gewässer Potenzial der Seen und Flüsse für Wärmeentzug und Wärmeeinleitung
# Windenergieanlagen Windenergieanlagen
# Windgeschwindigkeit 100 m Höhe Windatlas Schweiz: Jahresmittel der modellierten Windgeschwindigkeit und Windrichtung in 100 m Höhe über Grund
# Windgeschwindigkeit 125 m Höhe Windatlas Schweiz: Jahresmittel der modellierten Windgeschwindigkeit und Windrichtung in 125 m Höhe über Grund
# Windgeschwindigkeit 150 m Höhe Windatlas Schweiz: Jahresmittel der modellierten Windgeschwindigkeit und Windrichtung in 150 m Höhe über Grund
# Windgeschwindigkeit 50 m Höhe Windatlas Schweiz: Jahresmittel der modellierten Windgeschwindigkeit und Windrichtung in 50 m Höhe über Grund
# Windgeschwindigkeit 75 m Höhe Windatlas Schweiz: Jahresmittel der modellierten Windgeschwindigkeit und Windrichtung in 75 m Höhe über Grund
# Windpotenzialgebiete Konzept Windenergie – Grundlagenkarte des Bundes betreffend die hauptsächlichen Windpotenzialgebiete
# Arealstatistik Standard Arealstatistik nach Standardnomenklatur NOAS04
# Arealstatistik Bedeckung Arealstatistik nach Bodenbedeckungsnomenklatur NOLC04
# Erreichbarkeit von Apotheken Dienstleistungen für die Bevölkerung: Erreichbarkeit von Apotheken
# Erreichbarkeit von Restaurants Dienstleistungen für die Bevölkerung: Erreichbarkeit von Restaurants
# Reflektierende Flächen Flugplätze Reflektierende Flächen im Nahbereich von Flugplätzen
# Administrative Grenzen G1, Agglomerationen Agglomerationen: Generalisierte Grenzen
# Bilddokumentation Landschaftswandel Landschaftswandel in der Schweiz
# Statistische Grundeinheiten Stufe 1 Raumbezogene statistische Grundeinheiten der ersten Stufe (USPAT1)
# Statistische Grundeinheiten Stufe 2 Raumbezogene statistische Grundeinheiten der zweiten Stufe (USPAT2)
# Gebäude Gebäude- und Wohnungsstatistik: Gebäude
# Wohnungen Gebäude- und Wohnungsstatistik: Wohnungen
# Alpprodukte Alpprodukte
# Bergprodukte Bergprodukte
# Bewässerungsbedürftigkeit Bewässerungsbedürftigkeit
# Gründigkeit Digitale Bodeneignungskarte der Schweiz - Gründigkeit
# Bodeneignung für Kulturland Digitale Bodeneignungskarte der Schweiz - Kulturland
# Bodeneignung: Kulturtyp Digitale Bodeneignungskarte der Schweiz - Kulturtyp
# Nährstoffspeichervermögen Digitale Bodeneignungskarte der Schweiz - Nährstoffspeichervermögen
# Skelettgehalt Digitale Bodeneignungskarte der Schweiz - Skelettgehalt
# Vernässung Digitale Bodeneignungskarte der Schweiz - Vernässung
# Wasserdurchlässigkeit Digitale Bodeneignungskarte der Schweiz - Wasserdurchlässigkeit
# Wasserspeichervermögen Digitale Bodeneignungskarte der Schweiz - Wasserspeichervermögen
# Erosionsrisiko Acker qualitativ Erosionsrisikokarte des Ackerlandes, qualitative Einstufung
# Fliesswegkarte Fliesswegkarte zum Erosionsrisiko
# Erosionsrisiko Acker quantitativ Erosionsrisikokarte des Ackerlandes, mittlerer Bodenabtrag in Tonnen/(ha*Jahr)
# Feldblockkarte Feldblockkarte zum Erosionsrisiko
# Gewässeranschluss Gewässeranschlusskarte, Anschlusswahrscheinlichkeit
# Gewässeranschluss erweitert Gewässeranschlusskarte direkt und indirekt, Anschlusswahrscheinlichkeit
# Hanglagen Abschwemmung Hanglagen Abschwemmung
# Hanglagen Hanglagen
# Klimaeignung Futterbau Klimaeignungskarte für die Landwirtschaft - Futterbau
# Klimaeignung Getreidebau Klimaeignungskarte für die Landwirtschaft - Getreidebau
# Klimaeignung Kartoffeln Klimaeignungskarte für die Landwirtschaft - Kartoffeln
# Klimaeignung Körnermais Klimaeignungskarte für die Landwirtschaft - Körnermais
# Klimaeignung Kulturland Klimaeignungskarte für die Landwirtschaft - Kulturland
# Klimaeignung Spezialkulturen Klimaeignungskarte für die Landwirtschaft - Spezialkulturen
# Klimaeignung Übersicht Klimaeignungskarte für die Landwirtschaft - Übersicht
# Klimaeignung Zwischenfruchtbau Klimaeignungskarte für die Landwirtschaft - Sommer-Zwischenfruchtbau
# Nutzungsflächen Landwirtschaftliche Nutzungsflächen Schweiz
# Milchmarktregionen Regionen der Marktbeobachtung Milch und Milchprodukte
# Niederschlagshaushalt Klimaeignungskarte für die Landwirtschaft - Niederschläge
# Rebflächen in Hanglagen Rebflächen in Hanglagen
# Amtliches Ortschaftenverzeichnis Amtliches Ortschaftenverzeichnis mit Postleitzahl und Perimeter
# Zonenpläne für den Notfallschutz Zonenpläne für die Notfallplanung in der Umgebung der Kernanlagen
# Hagelgefährdung (Korngrösse) 100 J. Hagelgefährdung auf Referenzfläche 100 m2: Korngrösse mit Wiederkehrperiode 100 Jahre
# Hagelgefährdung (Korngrösse), 10 J. Hagelgefährdung auf Referenzfläche 100 m2: Korngrösse mit Wiederkehrperiode 10 Jahre
# Hagelgefährdung (Korngrösse), 20 J. Hagelgefährdung auf Referenzfläche 100 m2: Korngrösse mit Wiederkehrperiode 20 Jahre
# Hagelgefährdung (Korngrösse), 50 J. Hagelgefährdung auf Referenzfläche 100 m2: Korngrösse mit Wiederkehrperiode 50 Jahre
# Niederschlag 1961-1990 (Klimanormwerte) Klimanormwerte Niederschlag 1961-1990
# Niederschlag 1991-2020 (Klimanormwerte) Klimanormwerte Niederschlag 1991-2020
# Sonnenscheindauer 1961-1990 (Klimanormwerte) Klimanormwerte Sonnenscheindauer 1961-1990
# Sonnenscheindauer 1991-2020 (Klimanormwerte) Klimanormwerte Sonnenscheindauer 1991-2020
# Temperatur 1961-1990 (Klimanormwerte) Klimanormwerte Temperatur 1961-1990
# Temperatur 1991-2020 (Klimanormwerte) Klimanormwerte Temperatur 1991-2020
# Klimaszenarien Raumklima Klimaszenarien fürs zukünftige Innenraumklima (SIA 2028)
# Thermale Wässer Thermale Wässer
# HUG-Messstationen Messstationen der hydrologischen Untersuchungsgebiete
# HUG Hydro. Untersuchungsgebiete Hydrologische Untersuchungsgebiete
# Hydrologische Messstationen Basismessnetz Oberflächengewässer
# Gefährdungskarte Oberflächenabfluss Gefährdungskarte Oberflächenabfluss
# Hochwasserwarnkarte Hochwasserwarnkarte
# Nationalpark Schweizerischer Nationalpark
# Thermische Netze Thermische Netze (Nahwärme, Fernwärme, Fernkälte)
# Lawinen (SilvaProtect-CH) SilvaProtect-CH (Gefahrenhinweise auf nationaler Stufe): Lawinen mit Anrissgebieten im Wald
# Pilot- und Demonstrationsprojekte Aktuelle Pilot- und Demonstrationsprojekte des Bundesamts für Energie
# Lagefixpunkte LFP2 Lagefixpunkte LFP2 (amtliche Vermessung)
# Gesamt-Phosphor Beurteilung des chemischen Gewässerzustandes: Gesamt-Phosphor
# Gelöster organ. Kohlenstoff (DOC) Beurteilung des chemischen Gewässerzustandes: Gelöster organischer Kohlenstoff (DOC)
# Höhenfixpunkte HFP2 Höhenfixpunkte HFP2 (amtliche Vermessung)
# SP Unterirdischer Gütertransport Sachplan Verkehr, Teil Unterirdischer Gütertransport (SUG)
# PKD (Proliferative Nierenkrankheit) Liste und Karte der PKD-Vorkommen (Fischkrankheit PKD)
# KbS öV Kataster der belasteten Standorte im Bereich des öffentlichen Verkehrs (KbS BAV)
# Krebspest Krebspest - Nachweis in der Schweiz
# Pollen Erle, 1 h Messwerte Erle, mittlere stündliche Pollenkonzentration
# Nasenlaichplätze Nasenlaichgebiete 1995 - 2004
# Pollen Eiche, 1 h Messwerte Eiche, mittlere stündliche Pollenkonzentration
# KbS Zivilflugplätze Kataster der belasteten Standorte im Bereich der zivilen Flugplätze (KbS BAZL)
# Trockenheitsindex Aktuelle Lage Trockenheit in der Schweiz
# Schweregrundnetz Landesschwerenetz
# Hindernisbegrenzungsflächen Hindernisbegrenzungsflächen-Kataster
# Aeromagnetik Aargau 1100 m 100 Aeromagnetische Karte 1:100000 Aargau bis Schaffhausen (1100 m)
# Aeromagnetik Aargau 1500 m 100 Aeromagnetische Karte 1:100000 Aargau bis Schaffhausen (1500 m)
# Pro Natura Naturschutzgebiete Pro Natura Naturschutzgebiete
# Sachplan CERN Anhörung Sachplan CERN Anhörung
# Einteilung swissSURFACE3D LiDAR Geografische Ausdehnung swissSURFACE3D
# Pollen Buche, 1 h Messwerte Buche, mittlere stündliche Pollenkonzentration
# Lithologie 500 Lithologische Karte der Schweiz 1:500000
# Pollen Birke, 1 h Messwerte Birke, mittlere stündliche Pollenkonzentration
# Niederschlagsumme, 72 h Messwerte Niederschlag, Summe der letzten 72 Stunden
# Bahnen/Skilifte Winter Bahnen und Skilifte mit Winterbetrieb
# DHM25 Reliefschattierung DHM25 Reliefschattierung
# LV95 Dreiecksvermaschung Bezugsrahmenwechsel LV03 - LV95: Dreiecksvermaschung (CHENyx06 und FINELTRA LV)
# Niederschlagsumme, 48 h Messwerte Niederschlag, Summe der letzten 48 Stunden
# AGNES Referenznetz (permanent): Automatisches GNSS Netz Schweiz (AGNES)
# Amphibien Anhang 3 Bundesinventar der Amphibienlaichgebiete von nationaler Bedeutung - Anhang 3
# Niederschlagsumme, 24 h Messwerte Niederschlag, Summe der letzten 24 Stunden
# Niederschlagsumme, 1 h Messwerte Niederschlag, Stundensumme
# Niederschlagsumme, 1 Tag Messwerte Niederschlag, Tagessumme
# Geoidmodell in CH1903 Geoidmodell CHGeo2004 in CH1903
# Geoidmodell in ETRS89 Geoidmodell CHGeo2004 in ETRS89
# Anthrop. Bodenunruhe CH Modell der menschengemachten seismischen Bodenunruhe der Schweiz
# Tiefe Bohrungen Tiefe Bohrungen
# Terrestrische Strahlung Terrestrische Strahlung
# Letzteiszeitl. Max. (Vektor) 500 Die Schweiz während des letzteiszeitlichen Maximums (LGM) 1:500000 (Vektorkarte)
# Letzteiszeitl. Max. (Karte) 500 Die Schweiz während des letzteiszeitlichen Maximums (LGM) 1:500000
# Felslabore Felslabore in der Schweiz
# Höhenmodell der Felsoberfläche Höhenmodell der Felsoberfläche
# Geol. Generalkarte 200 Geologische Generalkarte der Schweiz 1:200000
# Einteilung GGK 200 Raster Einteilung Geologische Generalkarte 200 Raster
# GeoCover - Vektordaten Geologische Vektordatensätze GeoCover
# Einteilung GeoCover Blatteinteilung geologische Vektordatensätze GeoCover
# Bouguer-Anomalien 500 Schwerekarte der Schweiz (Bouguer-Anomalien) 1:500000
# Isostatische Anomalien 500 Schwerekarte der Schweiz (Isostatische Anomalien) 1:500000
# GeoEvents auf Anfrage Erlebnis Geologie: GeoEvents auf Anfrage
# Temperatur 2 m, Min. heute Messwerte Lufttemperatur 2 m, Minimum des aktuellen Tages
# GeoEvents demnächst Erlebnis Geologie: GeoEvents demnächst
# Geologische 3D-Modelle Geologische 3D-Modelle in der Schweiz
# Geologie 500 Geologische Karte der Schweiz 1:500000
# Geologischer Atlas GA25 Geologischer Atlas der Schweiz 1:25000
# Einteilung GA25 Raster Einteilung Geologischer Atlas 25 Raster
# Geologische Profile GA25 Geologischer Atlas der Schweiz 1:25000 – Profile
# Niederschlagsumme, 10 min Messwerte Niederschlag, 10 min Summe
# Temperaturmodell - Daten Temperaturmodell des Untergrundes des Schweizer Mittellandes - Eingangsdaten und Grenze des Modells
# Temperaturen 1000 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 1000 m
# Temperaturen 1500 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 1500 m
# Temperaturen 2000 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 2000 m
# Temperaturen 3000 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 3000 m
# Temperaturen 4000 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 4000 m
# Temperaturen 500 m Tiefe Temperaturmodell des Untergrundes des Schweizer Mittellandes - Temperaturverteilung in einer Tiefe von 500 m
# Übersicht Geomorphologie Übersicht Geomorphologie
# Aeromagnetik Mittelland/Jura 500 Aeromagnetische Karte des Schweizerischen Mittellandes und Juras
# Aeromagnetik 500 Aeromagnetische Karte der Schweiz 1:500000
# Deklination 500 Deklinationskarte der Schweiz 1:500000
# Wärmestromdichte 500 Geothermische Karte der Schweiz 1:500000
# Inklination 500 Inklinationskarte der Schweiz 1:500000
# Magnetfeldstärke 500 Totalintensitätskarte der Schweiz 1:500000
# Geosites Erlebnis Geologie: Geosites
# Entstehung der Gesteine 500 Lithologische Karte der Schweiz – Genese 1:500000
# Gesteinsgruppen 500 Lithologische Karte der Schweiz – Gesteinsgruppen 1:500000
# Neuschnee, 3 Tage Messwerte Neuschneehöhe, Summe der letzten 3 Tage
# Naturwerksteine an Bauwerken Naturwerksteine an Bauwerken
# Geothermische Potenzialstudien Regionale geothermische Potenzialstudien in der Schweiz und im Fürstentum Liechtenstein
# Geotope der Schweiz Geotope der Schweiz
# Stand kantonale Geotope Stand der kantonalen Geotopinventare
# Geowege Erlebnis Geologie: Geowege
# Dichte von Gesteinen Dichte von Gesteinen
# Gletscherausdehnung Gletscherausdehnung
# Gletschermächtigkeit Gletschermächtigkeit
# Gravimetrischer Atlas 100 Gravimetrischer Atlas der Schweiz 1:100000
# Gravimetrische Messpunkte 100 Gravimetrischer Atlas der Schweiz: Messpunkte 1:100000
# Hartstein: Produktionsstandorte Hartstein: Produktions- und Abbaustandorte
# Hartstein: Vorkommen Hartstein: Mächtigkeit und Qualität der geologischen Vorkommen
# Grundwasservorkommen 500 Hydrogeologische Karte der Schweiz: Grundwasservorkommen 1:500000
# Grundwasservulnerabilität 500 Hydrogeologische Karte der Schweiz: Vulnerabilität der Grundwasservorkommen 1:500000
# Mächtigkeit des Lockergesteins Mächtigkeitsmodell des Lockergesteins
# Felsgebrochene Gesteinskörnungen Felsgebrochene Gesteinskörnungen
# Gips Rohstoffe, Produktion- und Abbaustandorte der Gipsindustrie
# Weitere Industrieminerale Weitere Industrieminerale
# Energierohstoffe Energierohstoffe
# Naturwerksteine Naturwerksteine
# Salz Salz
# Metallrohstoffe Metallrohstoffe
# ...
# Landeskarte 1:50'000 | LK50 Landeskarte 1:50'000
# Landeskarte Winter Landeskarten der Schweiz Winterdarstellung
# Einteilung Landeskarte 100 Raster Blatteinteilung Landeskarte 1:100'000 Swiss Map Raster
# Einteilung Landeskarte 200 Raster Blatteinteilung Landeskarte 1:200'000 Swiss Map Raster
# Einteilung Landeskarte 25 Raster Blatteinteilung Landeskarte 1:25'000 Swiss Map Raster
# Einteilung Landeskarte 50 Raster Blatteinteilung Landeskarte 1:50'000 Swiss Map Raster
# Schneeschuhwandern Langsamverkehr - Schneeschuhwandern
# Strassenkarte 1:200'000 Strassenkarte 1:200'000
# swissALTI3D multidirektionales Relief swissALTI3D Reliefschattierung multidirektional
# swissALTI3D monodirektionales Relief swissALTI3D Reliefschattierung monodirektional
# swissALTIRegio monodirektionales Relief swissALTIRegio Reliefschattierung monodirektional
# Luftdruck reduziert QNH, 10 min Messwerte Luftdruck reduziert mit Standardatmosphäre (QNH), 10 min Mittel
# Bezirksgrenzen swissBoundaries3D Bezirksgrenzen
# Gemeindegrenzen Gemeindegrenzen - Zeitreise
# Kantonsgrenzen swissBOUNDARIES3D Kantonsgrenzen
# Landesgrenzen swissBOUNDARIES3D Landesgrenzen
# Käse Register Ursprungsbezeichnungen (GUB) und geografische Angaben (GGA) Käse
# Luftdruck reduziert QFF, 10 min Messwerte Luftdruck reduziert auf Meereshöhe (QFF), 10 min Mittel
# Luftdruck QFE, 10 min Messwerte Luftdruck auf Barometerhöhe (QFE), 10 min Mittel
# Pollen Esche, 1 h Messwerte Esche, mittlere stündliche Pollenkonzentration
# Fokuskarte Vögel Fokuskarte Vögel der Umweltziele Landwirtschaft
# SWISSIMAGE HIST 1946 SWISSIMAGE HIST 1946: Das Orthophotomosaik der Schweiz von 1946
# Einteilung SWISSIMAGE Zeitreise Kachelung SWISSIMAGE Zeitreise
# Geopotentielle Höhe 850 hPa, 10 min Geopotentielle Höhe der 850 hPa-Fläche, 10 min Mittel
# Geopotentielle Höhe 700 hPa, 10 min Geopotentielle Höhe der 700 hPa-Fläche, Momentanwert 10 min
# Globalstrahlung, 1 Tag Messwerte Globalstrahlung, Tagesmittel
# Einteilung swissSURFACE3D Raster Geografische Ausdehnung swissSURFACE3D Raster
# swissSURFACE3D Raster monodirektionales Relief swissSURFACE3D Raster Reliefschattierung monodirektional
# swissSURFACE3D Raster multidirektionales Relief swissSURFACE3D Raster Reliefschattierung multidirektional
# Eisenbahn swissTLM3D swissTLM3D Eisenbahn
# Gewässer swissTLM3D swissTLM3D Gewässernetz
# Karte swissTLM (farbig) swissTLM-Map (farbig)
# Karte swissTLM (grau) swissTLM-Map (grau)
# Strassen und Wege swissTLM3D swissTLM3D Strassen und Wege
# Seilbahnen swissTLM3D swissTLM3D Übrige Bahn
# Wald swissTLM3D swissTLM3D Wald
# Wanderwege swissTLM3D Wanderwege
# Basisnetz swissTNE Verkehrsnetz CH - swissTNE Base
# HTRANS LHN95-LN02 Höhentransformation HTRANS LHN95-LN02
# LV95 Transformationsgenauigkeit Bezugsrahmenwechsel LV03 - LV95 : Kombinierte Transformationsgenauigkeitskarte
# Schatzkarte Schatzkarte
# Unterkünfte Winter Unterkünfte Winter
# Globalstrahlung, 10 min Messwerte Globalstrahlung, 10 min Mittel
# Schneehöhe, 1 Tag Messwerte Schneehöhe, manuell gemessen um 7:00
# Föhnindex, 10 min Messwerte Föhnindex, 10 min Wert
# Ladepunkte für Elektroautos Ladepunkte für Elektroautos
# Spannungsarme Gebiete Spannungsarme Gebiete
# Organische Böden CH 2024 Abschätzung der organischen Böden in der Schweiz 2024
# Schutzgebiete swissTLMRegio swissTLMRegio Schutzgebiete
# Einzelgebäude gen. swissTLMRegio swissTLMRegio Buildings
# Gewässernetz swissTLMRegio swissTLMRegio Hydrography
# Bodenbedeckung swissTLMRegio swissTLMRegio Landcover
# Einzelobjekte swissTLMRegio swissTLMRegio Miscellaneous
# Höhenkoten swissTLMRegio swissTLMRegio Höhenkoten
# Namen swissTLMRegio swissTLMRegio Names
# Öffentlicher Verkehr swissTLMRegio swissTLMRegio Transportation Öffentlicher Verkehr
# Strassennetz swissTLMRegio swissTLMRegio Transportation Strassennetz
# Anlagen VECTOR25 VECTOR25 Anlagen
# Einzelobjekte VECTOR25 VECTOR25 Einzelobjekte
# Gebäude VECTOR25 VECTOR25 Gebäude
# Gewässernetz VECTOR25 VECTOR25 Gewässernetz GWN07
# Hecken und Bäume VECTOR25 VECTOR25 Hecken und Bäume
# Primärflächen VECTOR25 VECTOR25 Primärflächen
# LV95 Verschiebungsvektoren TSP1 Bezugsrahmenwechsel LV03 - LV95: Verschiebungsvektoren der TSP1 - Punkte (LV03 - LV95)
# LV95 Verschiebungsvektoren TSP2 Bezugsrahmenwechsel LV03 - LV95: Verschiebungsvektoren der TSP2 - Punkte (LV03 - LV95)
# Zeitreise - Kartenwerke Zeitreise - Topografische Kartenwerke
# Armee- und Kriegsdenkmäler Inventar der Armee- und Kriegsdenkmäler der Schweiz
# Armeelogistikcenter ALC Armeelogistikcenter
# Tankstellen BEBECO Bundestankstellen BEBECO
# Zeus Karte Grunddispositiv "Zeus"
# Ladestationen der Bundesverwaltung Ladestationen der Bundesverwaltung (BEBECO)
# Logistikräume ALC Logistikräume der Armeelogistikcenter
# Mil Airspace Chart Mil Airspace Chart 1:500'000
# Panzerverschiebungsrouten Panzerverschiebungsrouten
# Patrouille des Glaciers (A Rennen) Strecke Patrouille des Glaciers (A Rennen)
# Patrouille des Glaciers (Z Rennen) Strecke Patrouille des Glaciers (Z Rennen)
# Retablierungsstellen Retablierungsstellen der Armee
# SPM Anhörung Sachplan Militär - Anhörungen
# SP Militär Sachplan Militär
# Sperr- und Gefahrenzonenkarte Sperr- und Gefahrenzonenkarte 1:300'000
# SWISS MIL PILOTS CHART SWISS MIL PILOTS CHART 1:500'000
# Territorialdivisionen Territorialdivisionen
# Waldschadenkarte - Projektil Waldschadenkarte - Projektil
# Koordinatennetz CH1903+/LV95 Koordinatennetz CH1903+/LV95
# Koordinatennetz CH1903/LV03 Koordinatennetz CH1903/LV03
# Koordinatennetz WGS84 Koordinatennetz WGS84
# Lage Fliessgewässer und Seen Allgemeine Lage der Fliessgewässer und Seen
# Hydrol. Stationen Vorhersagen Hydrologische Stationen mit Vorhersagen
# Schutzgebiete Liechtenstein AuLaV Schutzgebiete der zivilen Luftfahrthindernispublikation – Schutzgebiete Liechtenstein
# Raster Verbreitungskarten Raster Verbreitungskarten
# Historische Erdbeben Karte der historischen Erdbeben in der Schweiz und im grenznahem Ausland
# Wassertemperatur der Flüsse Wassertemperatur der Flüsse
# ÖV-Güteklassen ARE ÖV-Güteklassen ARE
# Überschwemmung Aquaprotect 250 Überschwemmungsgebiete Aquaprotect: Wiederkehrperiode 250 Jahre
# Überschwemmung Aquaprotect 100 Überschwemmungsgebiete Aquaprotect: Wiederkehrperiode 100 Jahre
# Smaragd Smaragd Gebiete
# Landschaftstypologie Schweiz Landschaftstypologie Schweiz
# Bevölkerung (Einwohner) Bevölkerungsstatistik: Einwohner
# Erdbebenzonen SIA 261 Erdbebenzonen nach der Baunorm SIA 261
# Arbeitsstätten Betriebszählung/Unternehmensstatistik: Arbeitsstätten
# Begrenzungsflächen-Perimeter Perimeter der Hindernisbegrenzungsflächen
# Überschwemmung Aquaprotect 50 Überschwemmungsgebiete Aquaprotect: Wiederkehrperiode 50 Jahre
# Grundwasserstände/Quellschüttungen Allgemeine Lage der Grundwasserstände und Quellschüttungen
# Grundwassertemperatur Grundwassertemperatur
# Biosphärenreservate Biosphärenreservate
# Wildtierkorridore Überregional Wildtierkorridore Überregional
# Atlas Welten&Sutter Atlas Welten&Sutter
# Biogeographische Regionen Biogeographische Regionen der Schweiz (CH)
# Grundwasser: Nitrat Nitrat im Grundwasser (Nationale Grundwasserbeobachtung NAQUA)
# Wetterkameras Wetterkameras
# Pollenstationen Messstationen des nationalen Pollenmessnetzes
# Seismische Baugrundklassen Karte der seismischen Baugrundklassen nach der Baunorm SIA 261
# Phänologische Beobachtungen Phänologische Beobachtungen
# Hochwasser Gefahrenstufen Vergleich von Abfluss- und Pegeldaten mit den Gefahrenstufen
# Luftdruckänderung, 3 h Messwerte Luftdruckänderung seit den letzten 3 Stunden
# Vernetzungssystem Wildtiere Vernetzungssystem Wildtiere
# Überschwemmung Aquaprotect 500 Überschwemmungsgebiete Aquaprotect: Wiederkehrperiode 500 Jahre
# Pollen Gräser, 1 h Messwerte Gräser, mittlere stündliche Pollenkonzentration
# Schwingrasen Inventar der Schwingrasen
# Pollen Hasel, 1 h Messwerte Hasel, mittlere stündliche Pollenkonzentration
# Schneehöhe, 10 min Messwerte Schneehöhe, automatisch gemessen 10 min
# Sturmschaden Lothar Sturmschadeninventar LOTHAR 1999
# Sonnenscheindauer, 10 min Messwerte Sonnenscheindauer, 10 min Summe
# Gelände Vector Tileset Vektorielles Gelände (Vector Tileset)
# Sonnenscheindauer heute Messwerte Sonnenscheindauer, Summe aktueller Tag
# Beschäftigte (VZÄ) Betriebszählung/Unternehmensstatistik: Beschäftigte (VZÄ)
# Grundwasser: VOC Flüchtige organische Verbindungen VOC im Grundwasser (Nationale Grundwasserbeobachtung NAQUA)
# Sonnenscheindauer gestern Messwerte Sonnenscheindauer, Summe gestern
# Sturmschaden Vivian Waldschadenflächen Vivian 1990
# Spektrale Mikrozonierung Perimeter der vorhandenen spektralen Mikrozonierungsstudien
# MeteoSchweiz-Partnerstationen Stationen der MeteoSchweiz-Partnernetze
# Amtliches Strassenverzeichnis Amtliches Verzeichnis der Strassen
# Taupunkt, 10 min Messwerte Taupunkt, 10 min Mittel
# Schutzgebiete MIL Schutzgebiete der militärischen Luftfahrthindernispublikation
# Windböe 1 s, Max. 10 min Messwerte Wind Böenspitze 1 s, 10 min Maxima
# Windböe 1 s, Max. 6 h Messwerte Wind Böenspitze 1 s, Maximum der letzten 6 Stunden
# Manuelle Niederschlagsmessstationen Manuelle Schnee- und Niederschlagsmessstationen
# Klimastationen Stationen des Schweizer Klimamessnetzes
# Ausbreitungskarte Triturus cristatus Amphibien Ausbreitungskarten - Triturus cristatus
# Ausbreitungskarte Hyla arborea Amphibien Ausbreitungskarten - Hyla arborea
# Ausbreitungskarte Epidalea calamita Amphibien Ausbreitungskarten - Epidalea calamita
# Ausbreitungskarte Bombia variegata Amphibien Ausbreitungskarten - Bombina variegata
# Ausbreitungskarte Alytes obstericans Amphibien Ausbreitungskarten - Alytes obstetricans
# Bedeutung Parzellen Amphibien Landwirtschaftliche Parzellen mit potenzieller Bedeutung für Amphibien, Flächen
# Messstationen Luftqualität Nationales Beobachtungsnetz für Luftfremdstoffe NABEL: Stationen
# Gemeindeinformationen - AV Gemeindeinformationen bezüglich der amtlichen Vermessung
# Flugplatzstationen Beobachtungsstationen für Flugwetter
# Grundbuchinformationen Grundbuchinformationen
# Windgeschwindigkeit, 10 min Messwerte Wind Geschwindigkeit, 10 min Mittel
# Spitallandeplätze Spitallandeplätze: Landestellen zur Hilfeleistung
# SP Asyl Sachplan Asyl (SPA)
# Nachführungsgeometer/in Nachführungsgeometer/in
# OpenData-AV Amtliche Vermessung (OpenData)
# Periodische Nachführung Periodische Nachführung
# Kantone LFI Kantone LFI
# Radio- und Fernsehsender Schweizerische Radio- und Fernsehsender
# Niederschlagserosivität Mai Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Mai
# Stand der amtlichen Vermessung Stand der amtlichen Vermessung
# Geografische Namen swissNAMES3D swissNAMES3D Geografische Namen der Landesvermessung
# Spirituosen Register Ursprungsbezeichnungen (GUB) und geografische Angaben (GGA) Spirituosen
# Verfügbarkeit des ÖREB-Katasters ÖREB-Kataster: Verfügbarkeit der Informationen
# Basisgebiet Basisgebiete (Einzugsgebiete) HADES
# Messstandorte Gewässerzustand CH Messstandorte Gewässerzustand CH
# Grundwasserkörper Grundwasserkörper der Schweiz
# Auen ausserhalb Bundesinventar Auengebiete ausserhalb Bundesinventar
# ARA - Reinigungstyp Kläranlagendatenbank (ARA-DB) - Reinigungstyp
# ARA - Ausbaugrösse (EGW) Kläranlagendatenbank (ARA-DB) - Ausbaugrösse (EGW)
# ARA - Abwasserant. an Q347 Kläranlagendatenbank (ARA-DB) - Prozentanteil Abwasser im Vorfluter bei Niedrigwasser
# Niederschlagserosivität Sep. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, September
# Niederschlagserosivität Okt. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Oktober
# Meteorologische Beobachtungen Meteorologische Augenbeobachtungen
# Niederschlagserosivität Nov. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, November
# Niederschlagserosivität März Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, März
# Niederschlagserosivität Juni Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Juni
# Niederschlagserosivität Juli Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Juli
# Niederschlagserosivität Jan. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Januar
# Niederschlagserosivität Feb. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Februar
# SOLID Bund, Geschiebe Datenbank Geschiebefrachten (Bund)
# Städte und Agglomerationen BeSA Beitragsberechtigte Städte und Agglomerationen
# Niederschlagserosivität Dez. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, Dezember
# TWW Anhang 2 Bundesinventar der Trockenwiesen und -weiden von nationaler Bedeutung - Anhang 2
# Vegetation alpine Auen Vegetation alpine Auen
# CO₂-Emissionen Gebäude (SIA 380/1) Schätzung der direkten CO₂-Emissionen aufgrund des Wärmebedarfs gemäss SIA -Norm 380/1 (2016)
# Automatische Wetterstationen Automatische meteorologische Bodenmessstationen
# Atmosphärenstationen Atmosphärenstationen
# Niederschlagserosivität Aug. Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, August
# Niederschlagserosivität April Monatliche Niederschlagserosivitätskarten (R-Faktor) der Schweiz in MJ mm ha⁻¹ h⁻¹ Monat⁻¹, April
# Hangmuren (SilvaProtect-CH) SilvaProtect-CH (Gefahrenhinweis auf nationaler Stufe): Hangmuren
# Murgang (SilvaProtect-CH) SilvaProtect-CH (Gefahrenhinweis auf nationaler Stufe): Murgang
# Übersarung (SilvaProtect-CH) SilvaProtect-CH (Gefahrenhinweis auf nationaler Stufe): Übersarung
# Flussordnung Flussordnungszahl nach Strahler
# Erosionsrisiko Dauergrünland Sep. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), September
# Erosionsrisiko Dauergrünland Okt. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Oktober
# Erosionsrisiko Dauergrünland Nov. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), November
# Erosionsrisiko Dauergrünland März Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), März
# Sturz (SilvaProtect-CH) SilvaProtect-CH (Gefahrenhinweis auf nationaler Stufe): Sturz
# Erosionsrisiko Dauergrünland Mai Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Mai
# swissALTIRegio multidirektionales Relief swissALTIRegio Reliefschattierung multidirektional
# Erosionsrisiko Dauergrünland Juni Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Juni
# Erosionsrisiko Dauergrünland Juli Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Juli
# Erosionsrisiko Dauergrünland Jan. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Januar
# Reisezeit zu Agglos ÖV Reisezeit zu Agglomerationen und Kerngemeinden mit dem öffentlichen Verkehr
# Erosionsrisiko Dauergrünland Feb. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Februar
# Reisezeit zu Zentren Strasse Reisezeit zu 6 grossen Zentren auf der Strasse
# Reisezeit zu Agglos Strasse Reisezeit zu Agglomerationen und Kerngemeinden auf der Strasse
# Personen-/Güterverkehr Strasse Belastung (Fahrzeuge) des schweizerischen Strassennetzes nach Fahrzeugkategorien (Personen- und Güterverkehr)
# Personenverkehr Schiene Belastung (Personen) des schweizerischen Schienennetzes (Personenverkehr)
# Reisezeit zu Zentren ÖV Reisezeit zu 6 grossen Zentren mit dem öffentlichen Verkehr
# Erosionsrisiko Dauergrünland Dez. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), Dezember
# Erosionsrisiko Dauergrünland Aug. Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), August
# Erosionsrisiko Dauergrünland April Monatliche Erosionsrisikokarten des Schweizer Dauergrünlands, mittlerer Bodenabtrag in Tonnen/(ha*Monat), April
# Badegewässerqualität Badegewässerqualität

# %% [markdown]
# De la même manière, la méthode `.get()` accepte des headers sous la forme d'un dictionnaire :

# %%
import requests

# L'adresse suivante permet de demander l'analyse morphologique d'un terme :
url = "http://morph.alpheios.net/api/v1/analysis/word?word=lasciva&lang=lat&engine=whitakerLat"

xml = requests.get(url, headers={"Accept": "text/xml"})
print(xml.text)
req_json = requests.get(url, headers={"Accept": "application/json"})
print(req_json.text)
# Out:
# <rdf:RDF xmlns:rdf="http://www.w3.org/1999/02/22-rdf-syntax-ns#">
#   <oac:Annotation xmlns:oac="http://www.openannotation.org/ns/" rdf:about="urn:TuftsMorphologyService:lasciva:whitakerLat">
#     <dcterms:creator xmlns:dcterms="http://purl.org/dc/terms/">
#       <foaf:Agent xmlns:foaf="http://xmlns.com/foaf/0.1/" rdf:about="net.alpheios:tools:wordsxml.v1"/>
#     </dcterms:creator>
#     <dcterms:created xmlns:dcterms="http://purl.org/dc/terms/">2025-08-18T10:08:32.453697</dcterms:created>
#     <dc:rights xmlns:dc="http://purl.org/dc/elements/1.1/">Short definitions and morphology from Words by William Whitaker, Copyright 1993-2007.</dc:rights>
#     <oac:hasTarget>
#       <rdf:Description rdf:about="urn:word:lasciva"/>
#     </oac:hasTarget>
#     <dc:title xmlns:dc="http://purl.org/dc/elements/1.1/"/>
#     <oac:hasBody rdf:resource="urn:uuid:idm139936307545640"/>
#     <oac:Body rdf:about="urn:uuid:idm139936307545640">
#       <rdf:type rdf:resource="cnt:ContentAsXML"/>
#       <cnt:rest xmlns:cnt="http://www.w3.org/2008/content#">
#         <entry>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="7">nominative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="1">vocative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="3">ablative</case>
#             <num>singular</num>
#             <gend>feminine</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="7">nominative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="1">vocative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <infl>
#             <term xml:lang="lat">
#               <stem>lasciv</stem>
#               <suff>a</suff>
#             </term>
#             <pofs order="4">adjective</pofs>
#             <decl>1st</decl>
#             <var>1st</var>
#             <case order="4">accusative</case>
#             <num>plural</num>
#             <gend>neuter</gend>
#             <comp>positive</comp>
#           </infl>
#           <dict>
#             <hdwd xml:lang="lat">lascivus, lasciva, lascivum</hdwd>
#             <pofs order="4">adjective</pofs>
#             <freq order="5">frequent</freq>
#           </dict>
#           <mean>playful; lustful, wanton; impudent, mischievous; free from restraint;</mean>
#         </entry>
#       </cnt:rest>
#     </oac:Body>
#   </oac:Annotation>
# </rdf:RDF>
#
# {"RDF": {"Annotation": {"about": "urn:TuftsMorphologyService:lasciva:whitakerLat", "creator": {"Agent": {"about": "net.alpheios:tools:wordsxml.v1"}}, "created": {"$": "2025-08-18T10:08:32.743743"}, "rights": {"$": "Short definitions and morphology from Words by William Whitaker, Copyright 1993-2007."}, "hasTarget": {"Description": {"about": "urn:word:lasciva"}}, "title": {}, "hasBody": {"resource": "urn:uuid:idm139936314630056"}, "Body": {"about": "urn:uuid:idm139936314630056", "type": {"resource": "cnt:ContentAsXML"}, "rest": {"entry": {"infl": [{"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 7, "$": "nominative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 1, "$": "vocative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 3, "$": "ablative"}, "num": {"$": "singular"}, "gend": {"$": "feminine"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 7, "$": "nominative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 1, "$": "vocative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}, {"term": {"lang": "lat", "stem": {"$": "lasciv"}, "suff": {"$": "a"}}, "pofs": {"order": 4, "$": "adjective"}, "decl": {"$": "1st"}, "var": {"$": "1st"}, "case": {"order": 4, "$": "accusative"}, "num": {"$": "plural"}, "gend": {"$": "neuter"}, "comp": {"$": "positive"}}], "dict": {"hdwd": {"lang": "lat", "$": "lascivus, lasciva, lascivum"}, "pofs": {"order": 4, "$": "adjective"}, "freq": {"order": 5, "$": "frequent"}}, "mean": {"$": "playful; lustful, wanton; impudent, mischievous; free from restraint;"}}}}}}}

# %% [markdown]
# ### 2.C Les autres types de requêtes :
#
# Le module possède de la même manière une méthode `requests.post()` qui prendra en plus un paramètre `data` tout comme il possède les méthodes :
#
# - `.update()`
# - `.delete()`
# - `.put()`
# - `.options()`
#
# Toutes ces requêtes prennent les mêmes paramètres que `.get()`

# %% [markdown]
# ----
#
# #### Ce que l'on a appris
#
# Pour finir cette section, voici un récapitulatif des concepts appris. Lisez la liste et posez des questions si certaines choses ne sont pas claires.
#
# - la structure d'une requête http et de sa réponse
# - `requests.get`
# - `requests.post` et les autres
# - `Response.json()`
# - `Response.status_code`
